# %%
# import set 
using Turing
using Distances
using LinearAlgebra
using LimberJack
using Interpolations
using GaussianProcess
using Plots
using QuadGK
using BlockDiagonals
using PrettyTables
using CSV
using DataFrames

# %%
supernovae = CSV.read("DES_Dovekie_HD.csv", DataFrame);

# %%
#supernovae[!, :"zHEL"][1:10]
# Out:
# 10-element Vector{Float64}:
#  0.02507
#  0.02528
#  0.02604
#  0.02403
#  0.02428
#  0.02441
#  0.02493
#  0.02551
#  0.02565
#  0.02385
