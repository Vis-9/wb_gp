# %%
using LimberJack
using Plots
using Turing
using QuadGK
using Interpolations

# %% [markdown]
# ## Data

# %%
# Generate some fake data
# Try different cosmologies
cosmo = LimberJack.Cosmology(Ωm=0.27, Ωb=0.04, h=0.7, σ8=0.77);
z_integ = cosmo.settings.zs;

# %%
z_hz_data  = sort(2.5 .* rand(30)) # random array of 30 z values sorted ascending (0 - 2.5)
hz_data    = cosmo.cpar.h*Ez(cosmo, z_hz_data)
hz_err = 0.1 .* hz_data
z_dm_data  = sort(2.5 .* rand(300)) # 300 z values for chi
dm_data    = cosmo.chi(z_dm_data)
dm_err = 0.1 .* dm_data
z_fs8_data = sort(2.5 .* rand(20)) # 20 z values for fs8
fs8_data   = cosmo.fs8z(z_fs8_data);
fs8_err = 0.1 .* fs8_data;

hz_lcdm = cosmo.cpar.h*Ez(cosmo, z_integ)
dm_lcdm = cosmo.chi(z_integ)
fs8_lcdm = cosmo.fs8z(z_integ);

# %%
# Create the plots
p1 = plot(z_hz_data, hz_data, yerr=hz_err, seriestype=:scatter,title="h(z)", legend=false)
p2 = plot(z_dm_data, dm_data, yerr=dm_err, seriestype=:scatter, title="Dm(z)", legend=false)
p3 = plot(z_fs8_data, fs8_data, yerr=fs8_err, seriestype=:scatter, title="fs8(z)", legend=false)

plot!(p1, z_integ, hz_lcdm, color=:black)
plot!(p2, z_integ, dm_lcdm, color=:black)
plot!(p3, z_integ, fs8_lcdm, color=:black)

# Combine them horizontally (1 row, 3 columns)
plot(p1, p2, p3, layout=(1,3), size=(900,300))

# %% [markdown]
# ## Modelling

# %%
# Let's now do some modelling
function Dm_from_Ez(ez, z_in, h)
    chis = similar(ez)
    # Annoyingly, we have to build an interpolator for quadgk
    ez_itp = LinearInterpolation(z_integ, ez, extrapolation_bc=Line())
    for i in 1:length(z_in)
        zz = z_in[i]
        chis[i] = quadgk(z -> 1.0/ez_itp(z), 0.0, zz, rtol=1E-5)[1]
        chis[i] *= LimberJack.CLIGHT_HMPC / h
    end
    return chis
end

function fs8_from_Ez(e, z_in, Ωm, σ8)
    nz = length(z_in)
    a = @.(1/(1+z_in))
    x = log.(1 .+ z_in)
    dx = x[2]-x[1]
    
    aa = reverse(a)
    ee = reverse(e)
    dd = fill!(similar(e), 0)
    yy = fill!(similar(e), 0)
    dd[1] = aa[1]
    yy[1] = aa[1]^3*ee[end]
    
    for i in 1:(nz-1)
        A0 = -1.5 * Ωm / (aa[i]*ee[i])
        B0 = -1. / (aa[i]^2*ee[i])
        A1 = -1.5 * Ωm / (aa[i+1]*ee[i+1])
        B1 = -1. / (aa[i+1]^2*ee[i+1])
        yy[i+1] = (1+0.5*dx^2*A0*B0)*yy[i] + 0.5*(A0+A1)*dx*dd[i]
        dd[i+1] = 0.5*(B0+B1)*dx*yy[i] + (1+0.5*dx^2*A0*B0)*dd[i]
    end
    
    y = reverse(yy)
    d = reverse(dd)
    fs8z = -σ8 .* y./ (a.^2 .*e.*d[1])

    return fs8z
end
# Out:
# fs8_from_Ez (generic function with 1 method)

# %%
ez_lcdm = hz_lcdm ./ hz_lcdm[1] 
dm_test = Dm_from_Ez(ez_lcdm, z_integ, hz_lcdm[1])
fs8_test = fs8_from_Ez(ez_lcdm, z_integ, cosmo.cpar.Ωm, cosmo.cpar.σ8);

# %%
# Compare output
p1 = plot(z_integ, (dm_test .- dm_lcdm)./dm_lcdm,  title=" delta - Dm(z)", legend=false)
p2 = plot(z_integ, (fs8_test .- fs8_lcdm)./fs8_lcdm, title=" delta - fs8(z)", legend=false)

# Combine them horizontally (1 row, 2 columns)
plot(p1, p2, layout=(1,2), size=(600,300))

# %% [markdown]
# ## Inference

# %%
# concatenate all data
using LinearAlgebra
z_data = vcat(z_hz_data, z_dm_data, z_fs8_data)
data = vcat(hz_data, dm_data, fs8_data)
data_err = vcat(hz_err, dm_err, fs8_err)
data_cov = Diagonal(data_err .^2);

# %%
@model function model(data)
    # Priors
    Ωm ~ Uniform(0.1, 0.5)
    h ~ Uniform(0.6, 0.8)
    σ8 ~ Uniform(0.6, 0.9)
    
    # Create cosmology
    cosmo = LimberJack.Cosmology(Ωm=Ωm, Ωb=0.04, h=h, σ8=σ8);
    
    # Model predictions
    ez_model := Ez(cosmo, z_integ)
    hz_model := h .* ez_model
    # Gaussian Process would go here
    dm_model := Dm_from_Ez(ez_model, z_integ, h)
    fs8_model := fs8_from_Ez(ez_model, z_integ, Ωm, σ8)

    hz_itp = LinearInterpolation(z_integ, hz_model, extrapolation_bc=Line())
    dm_itp = LinearInterpolation(z_integ, dm_model, extrapolation_bc=Line())
    fs8_itp = LinearInterpolation(z_integ, fs8_model, extrapolation_bc=Line())

    hz_theory = hz_itp(z_hz_data)
    dm_theory = dm_itp(z_dm_data)
    fs8_theory = fs8_itp(z_fs8_data)

    theory = vcat(hz_theory, dm_theory, fs8_theory)

    # Likelihood
    data .~ MvNormal(theory, data_cov)
end
# Out:
# model (generic function with 2 methods)

# %%
cond_model = model(data)
n_samples = 100
chain = sample(cond_model, NUTS(0.65), n_samples)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 0.2
# └ @ Turing.Inference /Users/vis/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:212
# Sampling   1%|▎                                         |  ETA: 0:05:17
# Sampling   1%|▌                                         |  ETA: 0:02:41
# Sampling   2%|▉                                         |  ETA: 0:01:49
# Sampling   3%|█▏                                        |  ETA: 0:01:22
# Sampling   3%|█▍                                        |  ETA: 0:01:06
# Sampling   4%|█▋                                        |  ETA: 0:00:56
# Sampling   5%|██                                        |  ETA: 0:00:48
# Sampling   5%|██▎                                       |  ETA: 0:00:42
# Sampling   6%|██▌                                       |  ETA: 0:00:38
# Sampling   7%|██▊                                       |  ETA: 0:00:34
# Sampling   7%|███▏                                      |  ETA: 0:00:31
# Sampling   8%|███▍                                      |  ETA: 0:00:29
# Sampling   9%|███▋                                      |  ETA: 0:00:27
# Sampling   9%|███▉                                      |  ETA: 0:00:25
# Sampling  10%|████▎                                     |  ETA: 0:00:23
# Sampling  11%|████▌                                     |  ETA: 0:00:22
# Sampling  11%|████▊                                     |  ETA: 0:00:21
# Sampling  12%|█████                                     |  ETA: 0:00:20
# Sampling  13%|█████▍                                    |  ETA: 0:00:19
# Sampling  13%|█████▋                                    |  ETA: 0:00:18
# Sampling  14%|█████▉                                    |  ETA: 0:00:18
# Sampling  15%|██████▏                                   |  ETA: 0:00:18
# Sampling  15%|██████▌                                   |  ETA: 0:00:17
# Sampling  16%|██████▊                                   |  ETA: 0:00:16
# Sampling  17%|███████                                   |  ETA: 0:00:16
# Sampling  17%|███████▎                                  |  ETA: 0:00:15
# Sampling  18%|███████▌                                  |  ETA: 0:00:15
# Sampling  19%|███████▉                                  |  ETA: 0:00:15
# Sampling  19%|████████▏                                 |  ETA: 0:00:14
# Sampling  20%|████████▍                                 |  ETA: 0:00:15
# Sampling  21%|████████▋                                 |  ETA: 0:00:14
# Sampling  21%|█████████                                 |  ETA: 0:00:14
# Sampling  22%|█████████▎                                |  ETA: 0:00:13
# Sampling  23%|█████████▌                                |  ETA: 0:00:13
# Sampling  23%|█████████▊                                |  ETA: 0:00:13
# Sampling  24%|██████████▏                               |  ETA: 0:00:12
# Sampling  25%|██████████▍                               |  ETA: 0:00:12
# Sampling  25%|██████████▋                               |  ETA: 0:00:12
# Sampling  26%|██████████▉                               |  ETA: 0:00:12
# Sampling  27%|███████████▎                              |  ETA: 0:00:12
# Sampling  27%|███████████▌                              |  ETA: 0:00:12
# Sampling  28%|███████████▊                              |  ETA: 0:00:11
# Sampling  29%|████████████                              |  ETA: 0:00:11
# Sampling  29%|████████████▍                             |  ETA: 0:00:11
# Sampling  30%|████████████▋                             |  ETA: 0:00:11
# Sampling  31%|████████████▉                             |  ETA: 0:00:10
# Sampling  31%|█████████████▏                            |  ETA: 0:00:10
# Sampling  32%|█████████████▌                            |  ETA: 0:00:10
# Sampling  33%|█████████████▊                            |  ETA: 0:00:10
# Sampling  33%|██████████████                            |  ETA: 0:00:10
# Sampling  34%|██████████████▎                           |  ETA: 0:00:09
# Sampling  35%|██████████████▌                           |  ETA: 0:00:09
# Sampling  35%|██████████████▉                           |  ETA: 0:00:09
# Sampling  36%|███████████████▏                          |  ETA: 0:00:09
# Sampling  37%|███████████████▍                          |  ETA: 0:00:09
# Sampling  37%|███████████████▋                          |  ETA: 0:00:08
# Sampling  38%|████████████████                          |  ETA: 0:00:08
# Sampling  39%|████████████████▎                         |  ETA: 0:00:08
# Sampling  39%|████████████████▌                         |  ETA: 0:00:08
# Sampling  40%|████████████████▊                         |  ETA: 0:00:08
# Sampling  41%|█████████████████▏                        |  ETA: 0:00:08
# Sampling  41%|█████████████████▍                        |  ETA: 0:00:08
# Sampling  42%|█████████████████▋                        |  ETA: 0:00:07
# Sampling  43%|█████████████████▉                        |  ETA: 0:00:07
# Sampling  43%|██████████████████▎                       |  ETA: 0:00:07
# Sampling  44%|██████████████████▌                       |  ETA: 0:00:07
# Sampling  45%|██████████████████▊                       |  ETA: 0:00:07
# Sampling  45%|███████████████████                       |  ETA: 0:00:07
# Sampling  46%|███████████████████▍                      |  ETA: 0:00:07
# Sampling  47%|███████████████████▋                      |  ETA: 0:00:06
# Sampling  47%|███████████████████▉                      |  ETA: 0:00:06
# Sampling  48%|████████████████████▏                     |  ETA: 0:00:06
# Sampling  49%|████████████████████▌                     |  ETA: 0:00:06
# Sampling  49%|████████████████████▊                     |  ETA: 0:00:06
# Sampling  50%|█████████████████████                     |  ETA: 0:00:06
# Sampling  51%|█████████████████████▎                    |  ETA: 0:00:06
# Sampling  51%|█████████████████████▌                    |  ETA: 0:00:06
# Sampling  52%|█████████████████████▉                    |  ETA: 0:00:06
# Sampling  53%|██████████████████████▏                   |  ETA: 0:00:05
# Sampling  53%|██████████████████████▍                   |  ETA: 0:00:05
# Sampling  54%|██████████████████████▋                   |  ETA: 0:00:05
# Sampling  55%|███████████████████████                   |  ETA: 0:00:05
# Sampling  55%|███████████████████████▎                  |  ETA: 0:00:05
# Sampling  56%|███████████████████████▌                  |  ETA: 0:00:05
# Sampling  57%|███████████████████████▊                  |  ETA: 0:00:05
# Sampling  57%|████████████████████████▏                 |  ETA: 0:00:05
# Sampling  58%|████████████████████████▍                 |  ETA: 0:00:05
# Sampling  59%|████████████████████████▋                 |  ETA: 0:00:05
# Sampling  59%|████████████████████████▉                 |  ETA: 0:00:05
# Sampling  60%|█████████████████████████▎                |  ETA: 0:00:04
# Sampling  61%|█████████████████████████▌                |  ETA: 0:00:04
# Sampling  61%|█████████████████████████▊                |  ETA: 0:00:04
# Sampling  62%|██████████████████████████                |  ETA: 0:00:04
# Sampling  63%|██████████████████████████▍               |  ETA: 0:00:04
# Sampling  63%|██████████████████████████▋               |  ETA: 0:00:04
# Sampling  64%|██████████████████████████▉               |  ETA: 0:00:04
# Sampling  65%|███████████████████████████▏              |  ETA: 0:00:04
# Sampling  65%|███████████████████████████▌              |  ETA: 0:00:04
# Sampling  66%|███████████████████████████▊              |  ETA: 0:00:04
# Sampling  67%|████████████████████████████              |  ETA: 0:00:04
# Sampling  67%|████████████████████████████▎             |  ETA: 0:00:04
# Sampling  68%|████████████████████████████▌             |  ETA: 0:00:03
# Sampling  69%|████████████████████████████▉             |  ETA: 0:00:03
# Sampling  69%|█████████████████████████████▏            |  ETA: 0:00:03
# Sampling  70%|█████████████████████████████▍            |  ETA: 0:00:03
# Sampling  71%|█████████████████████████████▋            |  ETA: 0:00:03
# Sampling  71%|██████████████████████████████            |  ETA: 0:00:03
# Sampling  72%|██████████████████████████████▎           |  ETA: 0:00:03
# Sampling  73%|██████████████████████████████▌           |  ETA: 0:00:03
# Sampling  73%|██████████████████████████████▊           |  ETA: 0:00:03
# Sampling  74%|███████████████████████████████▏          |  ETA: 0:00:03
# Sampling  75%|███████████████████████████████▍          |  ETA: 0:00:03
# Sampling  75%|███████████████████████████████▋          |  ETA: 0:00:03
# Sampling  76%|███████████████████████████████▉          |  ETA: 0:00:02
# Sampling  77%|████████████████████████████████▎         |  ETA: 0:00:02
# Sampling  77%|████████████████████████████████▌         |  ETA: 0:00:02
# Sampling  78%|████████████████████████████████▊         |  ETA: 0:00:02
# Sampling  79%|█████████████████████████████████         |  ETA: 0:00:02
# Sampling  79%|█████████████████████████████████▍        |  ETA: 0:00:02
# Sampling  80%|█████████████████████████████████▋        |  ETA: 0:00:02
# Sampling  81%|█████████████████████████████████▉        |  ETA: 0:00:02
# Sampling  81%|██████████████████████████████████▏       |  ETA: 0:00:02
# Sampling  82%|██████████████████████████████████▌       |  ETA: 0:00:02
# Sampling  83%|██████████████████████████████████▊       |  ETA: 0:00:02
# Sampling  83%|███████████████████████████████████       |  ETA: 0:00:02
# Sampling  84%|███████████████████████████████████▎      |  ETA: 0:00:02
# Sampling  85%|███████████████████████████████████▌      |  ETA: 0:00:02
# Sampling  85%|███████████████████████████████████▉      |  ETA: 0:00:01
# Sampling  86%|████████████████████████████████████▏     |  ETA: 0:00:01
# Sampling  87%|████████████████████████████████████▍     |  ETA: 0:00:01
# Sampling  87%|████████████████████████████████████▋     |  ETA: 0:00:01
# Sampling  88%|█████████████████████████████████████     |  ETA: 0:00:01
# Sampling  89%|█████████████████████████████████████▎    |  ETA: 0:00:01
# Sampling  89%|█████████████████████████████████████▌    |  ETA: 0:00:01
# Sampling  90%|█████████████████████████████████████▊    |  ETA: 0:00:01
# Sampling  91%|██████████████████████████████████████▏   |  ETA: 0:00:01
# Sampling  91%|██████████████████████████████████████▍   |  ETA: 0:00:01
# Sampling  92%|██████████████████████████████████████▋   |  ETA: 0:00:01
# Sampling  93%|██████████████████████████████████████▉   |  ETA: 0:00:01
# Sampling  93%|███████████████████████████████████████▎  |  ETA: 0:00:01
# Sampling  94%|███████████████████████████████████████▌  |  ETA: 0:00:01
# Sampling  95%|███████████████████████████████████████▊  |  ETA: 0:00:01
# Sampling  95%|████████████████████████████████████████  |  ETA: 0:00:00
# Sampling  96%|████████████████████████████████████████▍ |  ETA: 0:00:00
# Sampling  97%|████████████████████████████████████████▋ |  ETA: 0:00:00
# Sampling  97%|████████████████████████████████████████▉ |  ETA: 0:00:00
# Sampling  98%|█████████████████████████████████████████▏|  ETA: 0:00:00
# Sampling  99%|█████████████████████████████████████████▌|  ETA: 0:00:00
# Sampling  99%|█████████████████████████████████████████▊|  ETA: 0:00:00
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:10
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:10
# Chains MCMC chain (100×1215×1 Array{Float64, 3}):
#
# Iterations        = 51:1:150
# Number of chains  = 1
# Samples per chain = 100
# Wall duration     = 10.09 seconds
# Compute duration  = 10.09 seconds
# parameters        = Ωm, h, σ8, ez_model[1], ez_model[2], ez_model[3], ez_model[4], ez_model[5], ez_model[6], ez_model[7], ez_model[8], ez_model[9], ez_model[10], ez_model[11], ez_model[12], ez_model[13], ez_model[14], ez_model[15], ez_model[16], ez_model[17], ez_model[18], ez_model[19], ez_model[20], ez_model[21], ez_model[22], ez_model[23], ez_model[24], ez_model[25], ez_model[26], ez_model[27], ez_model[28], ez_model[29], ez_model[30], ez_model[31], ez_model[32], ez_model[33], ez_model[34], ez_model[35], ez_model[36], ez_model[37], ez_model[38], ez_model[39], ez_model[40], ez_model[41], ez_model[42], ez_model[43], ez_model[44], ez_model[45], ez_model[46], ez_model[47], ez_model[48], ez_model[49], ez_model[50], ez_model[51], ez_model[52], ez_model[53], ez_model[54], ez_model[55], ez_model[56], ez_model[57], ez_model[58], ez_model[59], ez_model[60], ez_model[61], ez_model[62], ez_model[63], ez_model[64], ez_model[65], ez_model[66], ez_model[67], ez_model[68], ez_model[69], ez_model[70], ez_model[71], ez_model[72], ez_model[73], ez_model[74], ez_model[75], ez_model[76], ez_model[77], ez_model[78], ez_model[79], ez_model[80], ez_model[81], ez_model[82], ez_model[83], ez_model[84], ez_model[85], ez_model[86], ez_model[87], ez_model[88], ez_model[89], ez_model[90], ez_model[91], ez_model[92], ez_model[93], ez_model[94], ez_model[95], ez_model[96], ez_model[97], ez_model[98], ez_model[99], ez_model[100], ez_model[101], ez_model[102], ez_model[103], ez_model[104], ez_model[105], ez_model[106], ez_model[107], ez_model[108], ez_model[109], ez_model[110], ez_model[111], ez_model[112], ez_model[113], ez_model[114], ez_model[115], ez_model[116], ez_model[117], ez_model[118], ez_model[119], ez_model[120], ez_model[121], ez_model[122], ez_model[123], ez_model[124], ez_model[125], ez_model[126], ez_model[127], ez_model[128], ez_model[129], ez_model[130], ez_model[131], ez_model[132], ez_model[133], ez_model[134], ez_model[135], ez_model[136], ez_model[137], ez_model[138], ez_model[139], ez_model[140], ez_model[141], ez_model[142], ez_model[143], ez_model[144], ez_model[145], ez_model[146], ez_model[147], ez_model[148], ez_model[149], ez_model[150], ez_model[151], ez_model[152], ez_model[153], ez_model[154], ez_model[155], ez_model[156], ez_model[157], ez_model[158], ez_model[159], ez_model[160], ez_model[161], ez_model[162], ez_model[163], ez_model[164], ez_model[165], ez_model[166], ez_model[167], ez_model[168], ez_model[169], ez_model[170], ez_model[171], ez_model[172], ez_model[173], ez_model[174], ez_model[175], ez_model[176], ez_model[177], ez_model[178], ez_model[179], ez_model[180], ez_model[181], ez_model[182], ez_model[183], ez_model[184], ez_model[185], ez_model[186], ez_model[187], ez_model[188], ez_model[189], ez_model[190], ez_model[191], ez_model[192], ez_model[193], ez_model[194], ez_model[195], ez_model[196], ez_model[197], ez_model[198], ez_model[199], ez_model[200], ez_model[201], ez_model[202], ez_model[203], ez_model[204], ez_model[205], ez_model[206], ez_model[207], ez_model[208], ez_model[209], ez_model[210], ez_model[211], ez_model[212], ez_model[213], ez_model[214], ez_model[215], ez_model[216], ez_model[217], ez_model[218], ez_model[219], ez_model[220], ez_model[221], ez_model[222], ez_model[223], ez_model[224], ez_model[225], ez_model[226], ez_model[227], ez_model[228], ez_model[229], ez_model[230], ez_model[231], ez_model[232], ez_model[233], ez_model[234], ez_model[235], ez_model[236], ez_model[237], ez_model[238], ez_model[239], ez_model[240], ez_model[241], ez_model[242], ez_model[243], ez_model[244], ez_model[245], ez_model[246], ez_model[247], ez_model[248], ez_model[249], ez_model[250], ez_model[251], ez_model[252], ez_model[253], ez_model[254], ez_model[255], ez_model[256], ez_model[257], ez_model[258], ez_model[259], ez_model[260], ez_model[261], ez_model[262], ez_model[263], ez_model[264], ez_model[265], ez_model[266], ez_model[267], ez_model[268], ez_model[269], ez_model[270], ez_model[271], ez_model[272 ...
# internals         = lp, n_steps, is_accept, acceptance_rate, log_density, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size
#
# Summary Statistics
#     parameters      mean       std      mcse   ess_bulk   ess_tail      rhat   ⋯
#         Symbol   Float64   Float64   Float64    Float64    Float64   Float64   ⋯
#
#             Ωm    0.2704    0.0051    0.0006    86.0265    73.5692    1.0095   ⋯
#              h    0.6998    0.0050    0.0006    59.1371    54.8565    1.0060   ⋯
#             σ8    0.7691    0.0141    0.0026    36.8065    28.7865    1.0662   ⋯
#    ez_model[1]    1.0000    0.0000       NaN        NaN        NaN       NaN   ⋯
#    ez_model[2]    1.0019    0.0000    0.0000    86.0265    73.5692    1.0095   ⋯
#    ez_model[3]    1.0038    0.0001    0.0000    86.0265    73.5692    1.0095   ⋯
#    ez_model[4]    1.0057    0.0001    0.0000    86.0265    73.5692    1.0095   ⋯
#    ez_model[5]    1.0077    0.0001    0.0000    86.0265    73.5692    1.0095   ⋯
#    ez_model[6]    1.0097    0.0002    0.0000    86.0265    73.5692    1.0095   ⋯
#    ez_model[7]    1.0117    0.0002    0.0000    86.0265    73.5692    1.0095   ⋯
#    ez_model[8]    1.0137    0.0003    0.0000    86.0265    73.5692    1.0095   ⋯
#    ez_model[9]    1.0158    0.0003    0.0000    86.0265    73.5692    1.0095   ⋯
#   ez_model[10]    1.0179    0.0003    0.0000    86.0265    73.5692    1.0095   ⋯
#   ez_model[11]    1.0200    0.0004    0.0000    86.0265    73.5692    1.0095   ⋯
#   ez_model[12]    1.0221    0.0004    0.0000    86.0265    73.5692    1.0095   ⋯
#   ez_model[13]    1.0243    0.0004    0.0001    86.0265    73.5692    1.0095   ⋯
#   ez_model[14]    1.0265    0.0005    0.0001    86.0265    73.5692    1.0095   ⋯
#        ⋮            ⋮         ⋮         ⋮         ⋮          ⋮          ⋮      ⋱
#                                                   1 column and 1186 rows omitted
#
# Quantiles
#     parameters      2.5%     25.0%     50.0%     75.0%     97.5%
#         Symbol   Float64   Float64   Float64   Float64   Float64
#
#             Ωm    0.2605    0.2669    0.2704    0.2739    0.2800
#              h    0.6908    0.6964    0.7000    0.7033    0.7085
#             σ8    0.7375    0.7613    0.7681    0.7751    0.7966
#    ez_model[1]    1.0000    1.0000    1.0000    1.0000    1.0000
#    ez_model[2]    1.0018    1.0019    1.0019    1.0019    1.0020
#    ez_model[3]    1.0037    1.0038    1.0038    1.0039    1.0039
#    ez_model[4]    1.0055    1.0057    1.0057    1.0058    1.0060
#    ez_model[5]    1.0074    1.0076    1.0077    1.0078    1.0080
#    ez_model[6]    1.0093    1.0096    1.0097    1.0098    1.0100
#    ez_model[7]    1.0113    1.0116    1.0117    1.0119    1.0121
#    ez_model[8]    1.0132    1.0136    1.0137    1.0139    1.0142
#    ez_model[9]    1.0152    1.0156    1.0158    1.0160    1.0164
#   ez_model[10]    1.0172    1.0176    1.0179    1.0181    1.0185
#   ez_model[11]    1.0193    1.0197    1.0200    1.0202    1.0207
#   ez_model[12]    1.0213    1.0218    1.0221    1.0224    1.0229
#   ez_model[13]    1.0234    1.0240    1.0243    1.0246    1.0251
#   ez_model[14]    1.0255    1.0261    1.0265    1.0268    1.0274
#        ⋮            ⋮         ⋮         ⋮         ⋮         ⋮
#                                                  1186 rows omitted
