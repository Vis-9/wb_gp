# %% [markdown]
# # Setting up a latent function Gaussian Process for H(z)

# %%
# import set 
using Turing
using Distances
using LinearAlgebra
using LimberJack
using Interpolations
using GaussianProcess
using Plots
using QuadGK
using BlockDiagonals
using CSV
using DataFrames

# %% [markdown]
# ### Collate data

# %%
# setting a cosmology for the fake data, all fiducial cosmo parameters 
cosmo1 = Cosmology();
rd_fid = 99.0792;

# assumed parameter distributions
omegam_dist = Uniform(0.25, 0.35);
h0_dist = Uniform(0.6, 0.8);
s8_dist = Uniform(0.6, 0.9);
rd_dist = Uniform(90, 110);
M_dist = Normal(-19.3, 0.1);

# adaptation and sample steps for GP posterior
nadapts = 10;
nsamp = 50;

# %% [markdown]
# #### Generate fake data

# %%
# hz data
function fakedata_hz()
z  = sort(2.5 .* rand(30)) # random array of 30 z values sorted ascending (0 - 2.5)
data  = cosmo1.cpar.h*100*Ez(cosmo1, z)
err = 0.1 .* data
cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_hz", z = z, data = data, cov = cov)
end

# chi data
function fakedata_dm()
    z = sort(2.5 .* rand(300))
    data = cosmo1.chi(z)
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_dm", z = z, data = data, cov = cov)
end

# fs8 data
function fakedata_fs8()
    z = sort([[0.01, 0.02, 0.07] ; (2.5 .* rand(5))])
    data = fs8(cosmo1, z)
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return(data_name = "fakedata_fs8", z = z, data = data, cov = cov)
end

# aiso data
function fakedata_aiso()
z  = sort(2.5 .* rand(12)) 
dvz_cb = ((z .* LimberJack.CLIGHT_HMPC) .* ((cosmo1.chi(z)) .^ 2)) ./ (cosmo1.cpar.h .* 100 .* Ez(cosmo1, z))
data = (dvz_cb .^ (1/3)) ./ rd_fid
err = 0.1 .* data
cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_aiso", z = z, data = data, cov = cov)
end

# aap data
function fakedata_aap()
    z = sort([[0.01, 0.02, 0.03, 0.05, 0.06, 0.07] ; (2.5 .* rand(4))])
    data = LimberJack.CLIGHT_HMPC ./ (cosmo1.cpar.h .* 100 .* Ez(cosmo1, z) .* (cosmo1.chi(z)))
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_aap", z = z, data = data, cov = cov)
end

# supernovae data
function fakedata_mu()
    z = sort([[0.01, 0.02, 0.05, 0.09] ; (2.5 .* rand(4))])
    d_lum = (1 .+ z) .* (cosmo1.chi(z))
    data = 5 .* log10.(d_lum) .+ 25 .- 19.3
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return (data_name = "fakedata_mu", z = z, data = data, cov = cov)
end



fakedatahz = fakedata_hz();
fakedatadm = fakedata_dm();
fakedatafs8 = fakedata_fs8();
fakedataaap = fakedata_aap();
fakedataaiso = fakedata_aiso();
fakedatamu = fakedata_mu();

# %% [markdown]
# #### Putting Hz, Dm and fs8 data together

# %%
# fake data
data_obs  = [fakedatahz.data; fakedataaiso.data; fakedataaap.data; fakedatafs8.data; fakedatamu.data];
z_obs = [fakedatahz.z; fakedataaiso.z; fakedataaap.z; fakedatafs8.z; fakedatamu.z];
covariance_obs = BlockDiagonal([fakedatahz.cov, fakedataaiso.cov, fakedataaap.cov, fakedatafs8.cov, fakedatamu.cov]);

# correlation matrix
function cov_to_cor(covariance)
    std_devs = sqrt.(diag(covariance))
    return covariance ./ (std_devs * std_devs')
end

correlation_obs = cov_to_cor(covariance_obs)

# # derived covariance
# function corr_to_cov(correlation, scale)

# errors
hz_err = 0.1 .* fakedatahz.data;
aiso_err = 0.1 .* fakedataaiso.data;
aap_err = 0.1 .* fakedataaap.data;
fs8_err = 0.1 .* fakedatafs8.data;
mu_err = 0.1 .* fakedatamu.data;

# %% [markdown]
# ### Functions for hz, chi and fs8

# %%
# outputs are arrays, not interpolators
function hz_from_ez(zarr, h0, ez)
    ez_itp = LinearInterpolation(zarr, ez, extrapolation_bc=Line())
    hz = ez_itp(zarr) .* (h0*100)
    #hzi = linear_interpolation(zarr, hz, extrapolation_bc=Line())
    return hz
end

function dm_from_ez(zarr, h0, ez)
    chis = similar(ez)
    ez_itp = LinearInterpolation(zarr, ez, extrapolation_bc=Line())

    for i in 1:length(zarr)
        zz = zarr[i]
        chis[i] = quadgk(z -> 1.0/ez_itp(z), 0.0, zz, rtol=1E-5)[1]
        chis[i] *= LimberJack.CLIGHT_HMPC / h0
    end
    return chis
end


function fs8_from_ez(zarr, Ωm, σ8, h0, ez, cosmo_type)
    # initialising
    nz = length(zarr)
    z_max = maximum(zarr)
    x = log.(1 .+ zarr)
    a = @.(1/(1+zarr))
    dx = x[2]-x[1]
    
    aa = reverse(a)
    ee = reverse(ez)
    dd = zeros(cosmo_type, nz)
    yy = zeros(cosmo_type, nz)
    dd[1] = aa[1]
    yy[1] = aa[1]^3*ee[end]
    
    for i in 1:(nz-1)
        A0 = -1.5 * Ωm / (aa[i]*ee[i])
        B0 = -1. / (aa[i]^2*ee[i])
        A1 = -1.5 * Ωm / (aa[i+1]*ee[i+1])
        B1 = -1. / (aa[i+1]^2*ee[i+1])
        yy[i+1] = (1+0.5*dx^2*A0*B0)*yy[i] + 0.5*(A0+A1)*dx*dd[i]
        dd[i+1] = 0.5*(B0+B1)*dx*yy[i] + (1+0.5*dx^2*A0*B0)*dd[i]
    end
    
    y = reverse(yy)
    d = reverse(dd)

    fs8zi =  -σ8 .* y./ (a.^2 .*ez.*d[1])
                                
                        
    return fs8zi
end


function dh(zarr, h0, ez)
    dhz = LimberJack.CLIGHT_HMPC ./ (hz_from_ez(zarr, h0, ez))
    return dhz
end

function dv(zarr, h0, ez)
    chis = similar(ez)
    ez_itp = LinearInterpolation(zarr, ez, extrapolation_bc=Line())

    for i in 1:length(zarr)
        zz = zarr[i]
        chis[i] = quadgk(z -> 1.0/ez_itp(z), 0.0, zz, rtol=1E-5)[1]
        chis[i] *= LimberJack.CLIGHT_HMPC / h0
    end
    
    dvs = similar(chis)
    for i in 1:length(zarr)
        zz = zarr[i]
        dvz_cbrt = zz * (LimberJack.CLIGHT_HMPC/(ez_itp(zz)*h0*100)) * (chis[i]^2)
        dvs[i] = sign(dvz_cbrt) * abs(dvz_cbrt)^(1/3)
    end

    return dvs
end

function a_ap(zarr, h0, ez)
  numer = dh(zarr, h0, ez) ./ dm_from_ez(zarr, h0, ez)
  return numer 
end

function a_iso(zarr, h0, rd, ez)
    numer = dv(zarr, h0, ez) ./ rd
    return numer 
end

function d_lum(zarr, h0, ez)
    dlz = (1 .+ zarr) .* dm_from_ez(zarr, h0, ez)
    return dlz
end

function mu(zarr, h0, M, ez)
    muz = 5 .* log10.( abs.(d_lum(zarr, h0, ez)) ) .+ 25 .+ M
    return muz
end
# Out:
# mu (generic function with 1 method)

# %%
#z_integ1 = max.(cosmo1.settings.zs, 1e-12);
z_integ1 = cosmo1.settings.zs;
ez_test = Ez(cosmo1, z_integ1);

# %%
p0 = plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, seriestype=:scatter,title="H(z)", legend=false)
p1 = plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, seriestype=:scatter,title="aiso(z)", legend=false)
p2 = plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, seriestype=:scatter, title="aap(z)", legend=false)
p3 = plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, seriestype=:scatter, title="fs8(z)", legend=false)
p4 = plot(fakedatamu.z, fakedatamu.data, yerr=mu_err, seriestype=:scatter, title="mu(z)", legend=false)

plot!(p0, z_integ1, hz_from_ez(z_integ1, cosmo1.cpar.h, ez_test), color=:black)
plot!(p1, z_integ1, a_iso(z_integ1, cosmo1.cpar.h, rd_fid, ez_test), color=:black)
plot!(p2, z_integ1, a_ap(z_integ1, cosmo1.cpar.h, ez_test), color=:black)
plot!(p3, z_integ1, fs8_from_ez(z_integ1, cosmo1.cpar.Ωm, cosmo1.cpar.σ8, cosmo1.cpar.h, ez_test, eltype(ez_test)), color=:black)
plot!(p4, z_integ1, mu(z_integ1, cosmo1.cpar.h, -19.3 , ez_test), color=:black)

plot(p0, p1, p2, p3, p4, layout=(2,3), size=(900,600))

# %% [markdown]
# ## LCDM analysis

# %%
@model function LCDM_model(data, data_cov)
    # Priors
    omegam_pr ~ omegam_dist
    h0_pr ~ h0_dist
    s8_pr ~ s8_dist
    rd_pr ~ rd_dist
    M_pr ~ M_dist

    # Create cosmology
    cosmo_pr = LimberJack.Cosmology(Ωm=cosmo1.cpar.Ωm, Ωb=cosmo1.cpar.Ωb, h=cosmo1.cpar.h, σ8=s8_pr);
    
    # Model predictions
    ez_model = Ez(cosmo_pr, z_integ1)
    hz_model := hz_from_ez(z_integ1, h0_pr, ez_model)
    dv_rd_model := a_iso(z_integ1, h0_pr, rd_pr, ez_model) 
    dh_dm_model := a_ap(z_integ1, h0_pr, ez_model)
    fs8_model := fs8_from_ez(z_integ1, omegam_pr, s8_pr, h0_pr, ez_model, eltype(ez_model))
    mu_model := mu(z_integ1, h0_pr, M_pr, ez_model)

    # Create interpolators
    hz_itp = LinearInterpolation(z_integ1, hz_model, extrapolation_bc=Line())
    dvrd_itp = LinearInterpolation(z_integ1, dv_rd_model, extrapolation_bc=Line())
    dhdm_itp = LinearInterpolation(z_integ1, dh_dm_model, extrapolation_bc=Line())
    fs8_itp = LinearInterpolation(z_integ1, fs8_model, extrapolation_bc=Line())
    mu_itp = LinearInterpolation(z_integ1, mu_model, extrapolation_bc=Line())

    hz_theory := hz_itp(fakedatahz.z)
    dvrd_theory := dvrd_itp(fakedataaiso.z)
    dhdm_theory := dhdm_itp(fakedataaap.z)
    fs8_theory := fs8_itp(fakedatafs8.z)
    mu_theory := mu_itp(fakedatamu.z)

    theory = [hz_theory; dvrd_theory; dhdm_theory; fs8_theory; mu_theory]

    # Likelihood
    data ~ MvNormal(theory, data_cov)
end
# Out:
# LCDM_model (generic function with 2 methods)

# %%
cond_LCDM_model = LCDM_model(data_obs, covariance_obs)
chain_LCDM = sample(cond_LCDM_model, NUTS(20, 0.65), 100)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 0.8
# └ @ Turing.Inference /Users/vis/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:212
# Sampling   1%|▍                                         |  ETA: 0:41:30
# Sampling   2%|▊                                         |  ETA: 0:20:39
# Sampling   2%|█                                         |  ETA: 0:13:40
# Sampling   3%|█▍                                        |  ETA: 0:11:06
# Sampling   4%|█▊                                        |  ETA: 0:08:51
# Sampling   5%|██▏                                       |  ETA: 0:07:20
# Sampling   6%|██▌                                       |  ETA: 0:06:20
# Sampling   7%|██▊                                       |  ETA: 0:05:37
# Sampling   8%|███▏                                      |  ETA: 0:04:57
# Sampling   8%|███▌                                      |  ETA: 0:04:26
# Sampling   9%|███▉                                      |  ETA: 0:04:01
# Sampling  10%|████▎                                     |  ETA: 0:03:43
# Sampling  11%|████▌                                     |  ETA: 0:03:25
# Sampling  12%|████▉                                     |  ETA: 0:03:09
# Sampling  12%|█████▎                                    |  ETA: 0:02:55
# Sampling  13%|█████▋                                    |  ETA: 0:02:43
# Sampling  14%|██████                                    |  ETA: 0:02:33
# Sampling  15%|██████▎                                   |  ETA: 0:02:24
# Sampling  16%|██████▋                                   |  ETA: 0:02:15
# Sampling  17%|███████                                   |  ETA: 0:02:08
# Sampling  18%|███████▍                                  |  ETA: 0:02:02
# Sampling  18%|███████▊                                  |  ETA: 0:01:56
# Sampling  19%|████████                                  |  ETA: 0:01:51
# Sampling  20%|████████▍                                 |  ETA: 0:01:45
# Sampling  21%|████████▊                                 |  ETA: 0:01:41
# Sampling  22%|█████████▏                                |  ETA: 0:01:36
# Sampling  22%|█████████▌                                |  ETA: 0:01:32
# Sampling  23%|█████████▊                                |  ETA: 0:01:29
# Sampling  24%|██████████▏                               |  ETA: 0:01:25
# Sampling  25%|██████████▌                               |  ETA: 0:01:22
# Sampling  26%|██████████▉                               |  ETA: 0:01:19
# Sampling  27%|███████████▎                              |  ETA: 0:01:16
# Sampling  28%|███████████▌                              |  ETA: 0:01:14
# Sampling  28%|███████████▉                              |  ETA: 0:01:11
# Sampling  29%|████████████▎                             |  ETA: 0:01:09
# Sampling  30%|████████████▋                             |  ETA: 0:01:06
# Sampling  31%|█████████████                             |  ETA: 0:01:04
# Sampling  32%|█████████████▎                            |  ETA: 0:01:02
# Sampling  32%|█████████████▋                            |  ETA: 0:01:00
# Sampling  33%|██████████████                            |  ETA: 0:00:58
# Sampling  34%|██████████████▍                           |  ETA: 0:00:56
# Sampling  35%|██████████████▊                           |  ETA: 0:00:54
# Sampling  36%|███████████████                           |  ETA: 0:00:53
# Sampling  37%|███████████████▍                          |  ETA: 0:00:51
# Sampling  38%|███████████████▊                          |  ETA: 0:00:50
# Sampling  38%|████████████████▏                         |  ETA: 0:00:48
# Sampling  39%|████████████████▌                         |  ETA: 0:00:47
# Sampling  40%|████████████████▊                         |  ETA: 0:00:45
# Sampling  41%|█████████████████▏                        |  ETA: 0:00:44
# Sampling  42%|█████████████████▌                        |  ETA: 0:00:43
# Sampling  42%|█████████████████▉                        |  ETA: 0:00:42
# Sampling  43%|██████████████████▎                       |  ETA: 0:00:40
# Sampling  44%|██████████████████▌                       |  ETA: 0:00:39
# Sampling  45%|██████████████████▉                       |  ETA: 0:00:38
# Sampling  46%|███████████████████▎                      |  ETA: 0:00:37
# Sampling  47%|███████████████████▋                      |  ETA: 0:00:36
# Sampling  48%|████████████████████                      |  ETA: 0:00:35
# Sampling  48%|████████████████████▎                     |  ETA: 0:00:34
# Sampling  49%|████████████████████▋                     |  ETA: 0:00:33
# Sampling  50%|█████████████████████                     |  ETA: 0:00:33
# Sampling  51%|█████████████████████▍                    |  ETA: 0:00:32
# Sampling  52%|█████████████████████▊                    |  ETA: 0:00:31
# Sampling  52%|██████████████████████                    |  ETA: 0:00:30
# Sampling  53%|██████████████████████▍                   |  ETA: 0:00:29
# Sampling  54%|██████████████████████▊                   |  ETA: 0:00:28
# Sampling  55%|███████████████████████▏                  |  ETA: 0:00:27
# Sampling  56%|███████████████████████▌                  |  ETA: 0:00:27
# Sampling  57%|███████████████████████▊                  |  ETA: 0:00:26
# Sampling  57%|████████████████████████▏                 |  ETA: 0:00:25
# Sampling  58%|████████████████████████▌                 |  ETA: 0:00:24
# Sampling  59%|████████████████████████▉                 |  ETA: 0:00:24
# Sampling  60%|█████████████████████████▎                |  ETA: 0:00:23
# Sampling  61%|█████████████████████████▌                |  ETA: 0:00:22
# Sampling  62%|█████████████████████████▉                |  ETA: 0:00:22
# Sampling  62%|██████████████████████████▎               |  ETA: 0:00:21
# Sampling  63%|██████████████████████████▋               |  ETA: 0:00:20
# Sampling  64%|███████████████████████████               |  ETA: 0:00:20
# Sampling  65%|███████████████████████████▎              |  ETA: 0:00:19
# Sampling  66%|███████████████████████████▋              |  ETA: 0:00:19
# Sampling  67%|████████████████████████████              |  ETA: 0:00:18
# Sampling  68%|████████████████████████████▍             |  ETA: 0:00:17
# Sampling  68%|████████████████████████████▊             |  ETA: 0:00:17
# Sampling  69%|█████████████████████████████             |  ETA: 0:00:16
# Sampling  70%|█████████████████████████████▍            |  ETA: 0:00:16
# Sampling  71%|█████████████████████████████▊            |  ETA: 0:00:15
# Sampling  72%|██████████████████████████████▏           |  ETA: 0:00:15
# Sampling  72%|██████████████████████████████▌           |  ETA: 0:00:14
# Sampling  73%|██████████████████████████████▊           |  ETA: 0:00:14
# Sampling  74%|███████████████████████████████▏          |  ETA: 0:00:13
# Sampling  75%|███████████████████████████████▌          |  ETA: 0:00:13
# Sampling  76%|███████████████████████████████▉          |  ETA: 0:00:12
# Sampling  77%|████████████████████████████████▎         |  ETA: 0:00:12
# Sampling  78%|████████████████████████████████▌         |  ETA: 0:00:11
# Sampling  78%|████████████████████████████████▉         |  ETA: 0:00:11
# Sampling  79%|█████████████████████████████████▎        |  ETA: 0:00:10
# Sampling  80%|█████████████████████████████████▋        |  ETA: 0:00:10
# Sampling  81%|██████████████████████████████████        |  ETA: 0:00:09
# Sampling  82%|██████████████████████████████████▎       |  ETA: 0:00:09
# Sampling  82%|██████████████████████████████████▋       |  ETA: 0:00:09
# Sampling  83%|███████████████████████████████████       |  ETA: 0:00:08
# Sampling  84%|███████████████████████████████████▍      |  ETA: 0:00:08
# Sampling  85%|███████████████████████████████████▊      |  ETA: 0:00:07
# Sampling  86%|████████████████████████████████████      |  ETA: 0:00:07
# Sampling  87%|████████████████████████████████████▍     |  ETA: 0:00:06
# Sampling  88%|████████████████████████████████████▊     |  ETA: 0:00:06
# Sampling  88%|█████████████████████████████████████▏    |  ETA: 0:00:05
# Sampling  89%|█████████████████████████████████████▌    |  ETA: 0:00:05
# Sampling  90%|█████████████████████████████████████▊    |  ETA: 0:00:05
# Sampling  91%|██████████████████████████████████████▏   |  ETA: 0:00:04
# Sampling  92%|██████████████████████████████████████▌   |  ETA: 0:00:04
# Sampling  92%|██████████████████████████████████████▉   |  ETA: 0:00:03
# Sampling  93%|███████████████████████████████████████▎  |  ETA: 0:00:03
# Sampling  94%|███████████████████████████████████████▌  |  ETA: 0:00:03
# Sampling  95%|███████████████████████████████████████▉  |  ETA: 0:00:02
# Sampling  96%|████████████████████████████████████████▎ |  ETA: 0:00:02
# Sampling  97%|████████████████████████████████████████▋ |  ETA: 0:00:01
# Sampling  98%|█████████████████████████████████████████ |  ETA: 0:00:01
# Sampling  98%|█████████████████████████████████████████▎|  ETA: 0:00:01
# Sampling  99%|█████████████████████████████████████████▋|  ETA: 0:00:00
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:43
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:47
# Chains MCMC chain (100×1585×1 Array{Float64, 3}):
#
# Iterations        = 21:1:120
# Number of chains  = 1
# Samples per chain = 100
# Wall duration     = 44.19 seconds
# Compute duration  = 44.19 seconds
# parameters        = omegam_pr, h0_pr, s8_pr, rd_pr, M_pr, hz_model[1], hz_model[2], hz_model[3], hz_model[4], hz_model[5], hz_model[6], hz_model[7], hz_model[8], hz_model[9], hz_model[10], hz_model[11], hz_model[12], hz_model[13], hz_model[14], hz_model[15], hz_model[16], hz_model[17], hz_model[18], hz_model[19], hz_model[20], hz_model[21], hz_model[22], hz_model[23], hz_model[24], hz_model[25], hz_model[26], hz_model[27], hz_model[28], hz_model[29], hz_model[30], hz_model[31], hz_model[32], hz_model[33], hz_model[34], hz_model[35], hz_model[36], hz_model[37], hz_model[38], hz_model[39], hz_model[40], hz_model[41], hz_model[42], hz_model[43], hz_model[44], hz_model[45], hz_model[46], hz_model[47], hz_model[48], hz_model[49], hz_model[50], hz_model[51], hz_model[52], hz_model[53], hz_model[54], hz_model[55], hz_model[56], hz_model[57], hz_model[58], hz_model[59], hz_model[60], hz_model[61], hz_model[62], hz_model[63], hz_model[64], hz_model[65], hz_model[66], hz_model[67], hz_model[68], hz_model[69], hz_model[70], hz_model[71], hz_model[72], hz_model[73], hz_model[74], hz_model[75], hz_model[76], hz_model[77], hz_model[78], hz_model[79], hz_model[80], hz_model[81], hz_model[82], hz_model[83], hz_model[84], hz_model[85], hz_model[86], hz_model[87], hz_model[88], hz_model[89], hz_model[90], hz_model[91], hz_model[92], hz_model[93], hz_model[94], hz_model[95], hz_model[96], hz_model[97], hz_model[98], hz_model[99], hz_model[100], hz_model[101], hz_model[102], hz_model[103], hz_model[104], hz_model[105], hz_model[106], hz_model[107], hz_model[108], hz_model[109], hz_model[110], hz_model[111], hz_model[112], hz_model[113], hz_model[114], hz_model[115], hz_model[116], hz_model[117], hz_model[118], hz_model[119], hz_model[120], hz_model[121], hz_model[122], hz_model[123], hz_model[124], hz_model[125], hz_model[126], hz_model[127], hz_model[128], hz_model[129], hz_model[130], hz_model[131], hz_model[132], hz_model[133], hz_model[134], hz_model[135], hz_model[136], hz_model[137], hz_model[138], hz_model[139], hz_model[140], hz_model[141], hz_model[142], hz_model[143], hz_model[144], hz_model[145], hz_model[146], hz_model[147], hz_model[148], hz_model[149], hz_model[150], hz_model[151], hz_model[152], hz_model[153], hz_model[154], hz_model[155], hz_model[156], hz_model[157], hz_model[158], hz_model[159], hz_model[160], hz_model[161], hz_model[162], hz_model[163], hz_model[164], hz_model[165], hz_model[166], hz_model[167], hz_model[168], hz_model[169], hz_model[170], hz_model[171], hz_model[172], hz_model[173], hz_model[174], hz_model[175], hz_model[176], hz_model[177], hz_model[178], hz_model[179], hz_model[180], hz_model[181], hz_model[182], hz_model[183], hz_model[184], hz_model[185], hz_model[186], hz_model[187], hz_model[188], hz_model[189], hz_model[190], hz_model[191], hz_model[192], hz_model[193], hz_model[194], hz_model[195], hz_model[196], hz_model[197], hz_model[198], hz_model[199], hz_model[200], hz_model[201], hz_model[202], hz_model[203], hz_model[204], hz_model[205], hz_model[206], hz_model[207], hz_model[208], hz_model[209], hz_model[210], hz_model[211], hz_model[212], hz_model[213], hz_model[214], hz_model[215], hz_model[216], hz_model[217], hz_model[218], hz_model[219], hz_model[220], hz_model[221], hz_model[222], hz_model[223], hz_model[224], hz_model[225], hz_model[226], hz_model[227], hz_model[228], hz_model[229], hz_model[230], hz_model[231], hz_model[232], hz_model[233], hz_model[234], hz_model[235], hz_model[236], hz_model[237], hz_model[238], hz_model[239], hz_model[240], hz_model[241], hz_model[242], hz_model[243], hz_model[244], hz_model[245], hz_model[246], hz_model[247], hz_model[248], hz_model[249], hz_model[250], hz_model[251], hz_model[252], hz_model[253], hz_model[254], hz_model[255], hz_model[256], hz_model[257], hz_model[258], hz_model[259], hz_model[260], hz_model[261], hz_model[262], hz_model[263], hz_model[264], hz_model[265], hz_model[266], hz_model[267], hz_model[268], hz_model[269], hz_model[270],  ...
# internals         = lp, n_steps, is_accept, acceptance_rate, log_density, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size
#
# Summary Statistics
#     parameters       mean       std      mcse   ess_bulk   ess_tail      rhat  ⋯
#         Symbol    Float64   Float64   Float64    Float64    Float64   Float64  ⋯
#
#      omegam_pr     0.3063    0.0163    0.0025    54.8328    50.6924    1.0520  ⋯
#          h0_pr     0.6710    0.0125    0.0014    78.9144   101.7705    0.9918  ⋯
#          s8_pr     0.7920    0.0431    0.0066    41.2165    52.4503    1.0475  ⋯
#          rd_pr    99.1264    2.9315    0.3974    52.9724    46.9548    1.0172  ⋯
#           M_pr   -19.2987    0.0951    0.0105    74.3815    35.2985    1.0196  ⋯
#    hz_model[1]    67.0970    1.2521    0.1446    78.9144   101.7705    0.9918  ⋯
#    hz_model[2]    67.2379    1.2547    0.1450    78.9144   101.7705    0.9918  ⋯
#    hz_model[3]    67.3804    1.2574    0.1453    78.9144   101.7705    0.9918  ⋯
#    hz_model[4]    67.5247    1.2601    0.1456    78.9144   101.7705    0.9918  ⋯
#    hz_model[5]    67.6706    1.2628    0.1459    78.9144   101.7705    0.9918  ⋯
#    hz_model[6]    67.8183    1.2656    0.1462    78.9144   101.7705    0.9918  ⋯
#    hz_model[7]    67.9677    1.2684    0.1465    78.9144   101.7705    0.9918  ⋯
#    hz_model[8]    68.1189    1.2712    0.1468    78.9144   101.7705    0.9918  ⋯
#    hz_model[9]    68.2718    1.2740    0.1472    78.9144   101.7705    0.9918  ⋯
#   hz_model[10]    68.4266    1.2769    0.1475    78.9144   101.7705    0.9918  ⋯
#   hz_model[11]    68.5831    1.2798    0.1479    78.9144   101.7705    0.9918  ⋯
#   hz_model[12]    68.7415    1.2828    0.1482    78.9144   101.7705    0.9918  ⋯
#        ⋮            ⋮          ⋮         ⋮         ⋮          ⋮          ⋮     ⋱
#                                                   1 column and 1556 rows omitted
#
# Quantiles
#     parameters       2.5%      25.0%      50.0%      75.0%      97.5%
#         Symbol    Float64    Float64    Float64    Float64    Float64
#
#      omegam_pr     0.2806     0.2932     0.3032     0.3183     0.3358
#          h0_pr     0.6478     0.6613     0.6710     0.6801     0.6909
#          s8_pr     0.7059     0.7632     0.7966     0.8207     0.8728
#          rd_pr    92.3336    97.2669    98.8971   100.9167   104.8182
#           M_pr   -19.4835   -19.3680   -19.2925   -19.2316   -19.1335
#    hz_model[1]    64.7791    66.1282    67.0959    68.0095    69.0869
#    hz_model[2]    64.9151    66.2670    67.2368    68.1523    69.2320
#    hz_model[3]    65.0528    66.4075    67.3794    68.2968    69.3788
#    hz_model[4]    65.1920    66.5497    67.5236    68.4430    69.5273
#    hz_model[5]    65.3329    66.6935    67.6696    68.5909    69.6776
#    hz_model[6]    65.4755    66.8390    67.8172    68.7406    69.8296
#    hz_model[7]    65.6198    66.9863    67.9666    68.8920    69.9834
#    hz_model[8]    65.7657    67.1353    68.1178    69.0452    70.1391
#    hz_model[9]    65.9134    67.2860    68.2708    69.2003    70.2966
#   hz_model[10]    66.0628    67.4385    68.4255    69.3571    70.4559
#   hz_model[11]    66.2139    67.5928    68.5820    69.5158    70.6171
#   hz_model[12]    66.3668    67.7489    68.7404    69.6763    70.7802
#        ⋮            ⋮          ⋮          ⋮          ⋮          ⋮
#                                                       1556 rows omitted

# %%
# lcdm chains
hzdata_lcdm = group(chain_LCDM, :hz_model).value.data[:,:,1];
hzdata2_lcdm = group(chain_LCDM, :hz_theory).value.data[:,:,1];
aisodata_lcdm = group(chain_LCDM, :dv_rd_model).value.data[:,:,1];
aapdata_lcdm = group(chain_LCDM, :dh_dm_model).value.data[:,:,1];
fs8data_lcdm = group(chain_LCDM, :fs8_model).value.data[:,:,1];
mudata_lcdm = group(chain_LCDM, :mu_model).value.data[:,:,1];

# mean and standard deviation - lcdm
hz_lcdm_m, hz_lcdm_s = mean(hzdata_lcdm, dims=1), std(hzdata_lcdm, dims=1); 
hz2_lcdm_m, hz2_lcdm_s = mean(hzdata2_lcdm, dims=1), std(hzdata2_lcdm, dims=1); 
aiso_lcdm_m, aiso_lcdm_s = mean(aisodata_lcdm, dims=1), std(aisodata_lcdm, dims=1);
aap_lcdm_m, aap_lcdm_s = mean(aapdata_lcdm, dims=1), std(aapdata_lcdm, dims=1); 
fs8_lcdm_m, fs8_lcdm_s = mean(fs8data_lcdm, dims=1), std(fs8data_lcdm, dims=1); 
mu_lcdm_m, mu_lcdm_s = mean(mudata_lcdm, dims=1), std(mudata_lcdm, dims=1);

# %%
plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, label="Data H(z)", ms=2, seriestype=:scatter)
plot!(z_integ1, vec(hz_lcdm_m), label=" H(z) LCDM mean")
plot!(z_integ1, vec(hz_lcdm_m .- hz_lcdm_s),  fillrange = vec(hz_lcdm_m .+ hz_lcdm_s), fillalpha=0.2, c=1, label="H(z) LCDM standard deviation")

# %%
plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, label="Data a_iso", ms=2, seriestype=:scatter)
plot!(z_integ1, vec(aiso_lcdm_m), label=" a_iso LCDM mean")
plot!(z_integ1, vec(aiso_lcdm_m .- aiso_lcdm_s),  fillrange = vec(aiso_lcdm_m .+ aiso_lcdm_s), fillalpha=0.2, c=1, label="a_iso LCDM standard deviation")

# %%
plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, label="Data a_ap", ms=2, seriestype=:scatter)
plot!(z_integ1, vec(aap_lcdm_m), label="a_ap LCDM mean")
plot!(z_integ1, vec(aap_lcdm_m .- aap_lcdm_s),  fillrange = vec(aap_lcdm_m .+ aap_lcdm_s), fillalpha=0.2, c=1, label="a_ap LCDM standard deviation")

# %%
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(z_integ1, vec(fs8_lcdm_m), label="fs8 lcdm")
plot!(z_integ1, vec(fs8_lcdm_m .- fs8_lcdm_s),  fillrange = vec(fs8_lcdm_m .+ fs8_lcdm_s), fillalpha=0.2, c=1, label="fs8 lcdm standard deviation")

# %%
plot(fakedatamu.z, fakedatamu.data, yerr=mu_err, label="Data mu", ms=2, seriestype=:scatter)
plot!(z_integ1, vec(mu_lcdm_m), label="mu lcdm")
plot!(z_integ1, vec(mu_lcdm_m .- mu_lcdm_s),  fillrange = vec(mu_lcdm_m .+ mu_lcdm_s), fillalpha=0.2, c=1, label="mu lcdm standard deviation")

# %% [markdown]
# ## GP modelling - priors

# %%
zlat = range(0, 3.0, length=15); # latent variable space
z_integ = cosmo1.settings.zs; # integral variable space

# %%
function model_latent_GP(eta, l, v; omega_m=cosmo1.cpar.Ωm, sigma_8=cosmo1.cpar.σ8, h_0 = cosmo1.cpar.h,
                         x=zlat, z=z_obs, data_cov=covariance_obs)
    # Dimensions of predictors .
    kernel = sqexp_cov_fn(x; eta=eta, l=l)
    cpar = CosmoPar(Ωm=omega_m,  Ωb=cosmo1.cpar.Ωb, h=h_0, σ8=sigma_8)
    mean_ex = Ez(cpar, x)
    # a latent GP is carried out using a Wiener filter
    ex = latent_GP(mean_ex, v, kernel)
    # transforms hx from x space to z space
    ez =  conditional(x, z, ex, sqexp_cov_fn;
                     eta=eta, l=l)
    return ex, ez
end
# Out:
# model_latent_GP (generic function with 1 method)

# %% [markdown]
# hx is the GP realisation of the hubble parameter. hz transforms hx from the latent space to another parameter space (integral or observation).

# %%
N_samples = 100
# data parameter space conditional
exs1=zeros(N_samples, 15) #latent variable chain
ezs1=zeros(N_samples, length(z_obs)) #observed variable chain
# pick 100 random hyperparameter combinations, and compute the GP realisation of them in both latent and conditional space.
for i in 1:N_samples
    v = rand(MvNormal(zeros(length(zlat)), ones(length(zlat))))
    exs1[i, :], ezs1[i, :] = model_latent_GP(0.1, 0.3, v)
end
y_m1, y_s1 = mean(ezs1, dims=1), std(ezs1, dims=1); #observed space
gp_m1, gp_s1 = mean(exs1, dims=1), std(exs1, dims=1); #latent space

# %%
# integral parameter space conditional
exs2=zeros(N_samples, length(zlat))
ezs2=zeros(N_samples, length(z_integ))
hz_pr=zeros(N_samples, length(z_integ))
aiso_pr=zeros(N_samples, length(z_integ))
aap_pr=zeros(N_samples, length(z_integ))
fs8_pr=zeros(N_samples, length(z_integ))
mu_pr=zeros(N_samples, length(z_integ))

for i in 1:N_samples
    v = rand(MvNormal(zeros(length(zlat)), ones(length(zlat))))
    h_pr = rand(h0_dist)
    s8_pr = rand(s8_dist)
    omegam_pr = rand(omegam_dist)
    rd_pr = rand(rd_dist)
    M_pr = rand(M_dist)

    exs2[i, :], ezs2[i, :] = model_latent_GP(0.1, 0.3, v; z=z_integ, sigma_8=s8_pr)
    hz_pr[i, :] = hz_from_ez(z_integ, h_pr, ezs2[i, :])
    aiso_pr[i, :] = a_iso(z_integ, h_pr, rd_pr, ezs2[i, :])
    aap_pr[i, :] = a_ap(z_integ, h_pr, ezs2[i, :])
    fs8_pr[i, :] = fs8_from_ez(z_integ, omegam_pr, s8_pr, h_pr, ezs2[i, :], eltype(ezs2[i, :]))
    mu_pr[i, :] = mu(z_integ, h_pr, M_pr, ezs2[i, :])
end

y_m2, y_s2 = mean(ezs2, dims=1), std(ezs2, dims=1); #integral space
gp_m2, gp_s2 = mean(exs2, dims=1), std(exs2, dims=1); #latent space

hz_m2, hz_s2 = mean(hz_pr, dims=1), std(hz_pr, dims=1); 
aiso_m2, aiso_s2 = mean(aiso_pr, dims=1), std(aiso_pr, dims=1); 
aap_m2, aap_s2 = mean(aap_pr, dims=1), std(aap_pr, dims=1);
fs8_m2, fs8_s2 = mean(fs8_pr, dims=1), std(fs8_pr, dims=1);
mu_m2, mu_s2 = mean(mu_pr, dims=1), std(mu_pr, dims=1);

# %%
# prior model predictions
hz_itp2 = LinearInterpolation(z_integ, vec(hz_m2), extrapolation_bc=Line());
aiso_itp2 = LinearInterpolation(z_integ, vec(aiso_m2), extrapolation_bc=Line());
aap_itp2 = LinearInterpolation(z_integ, vec(aap_m2), extrapolation_bc=Line());
fs8_itp2 = LinearInterpolation(z_integ, vec(fs8_m2), extrapolation_bc=Line());
mu_itp2 = LinearInterpolation(z_integ, vec(mu_m2), extrapolation_bc=Line());

# %%
# integral space hz plot
plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, label="Data hz", ms=2, seriestype=:scatter)
plot!(z_integ, vec(hz_m2), label="hz mean")
plot!(z_integ, vec(hz_m2 .- hz_s2),  fillrange = vec(hz_m2 .+ hz_s2), fillalpha=0.2, c=1, label="hz standard deviation")

# %%
# integral space aiso plot
plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, label="Data a_iso", ms=2, seriestype=:scatter)
plot!(z_integ, vec(aiso_m2), label="a_iso mean")
plot!(z_integ, vec(aiso_m2 .- aiso_s2),  fillrange = vec(aiso_m2 .+ aiso_s2), fillalpha=0.2, c=1, label="a_iso standard deviation")

# %%
# plotting chi data 
plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, label="Data a_ap", ms=2, seriestype=:scatter)
plot!(z_integ, vec(aap_m2), label="a_ap mean")
plot!(z_integ, vec(aap_m2 .- aap_s2),  fillrange = vec(aap_m2 .+ aap_s2), fillalpha=0.2, c=1, label="a_ap standard deviation")

# %%
# plotting fs8 data 
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(z_integ, vec(fs8_m2), label="fs8 mean")
plot!(z_integ, vec(fs8_m2 .- fs8_s2),  fillrange = vec(fs8_m2 .+ fs8_s2), fillalpha=0.2, c=1, label="fs8 standard deviation")

# %%
# plotting supernovae data 
plot(fakedatamu.z, fakedatamu.data, yerr=mu_err, label="Data mu", ms=2, seriestype=:scatter)
plot!(z_integ, vec(mu_m2), label="mu mean")
plot!(z_integ, vec(mu_m2 .- mu_s2),  fillrange = vec(mu_m2 .+ mu_s2), fillalpha=0.2, c=1, label="mu standard deviation")

# %% [markdown]
# ## GP modelling - posteriors

# %%
@model function stats_model(y; int_grid=z_integ, X=zlat, data_x=z_obs, data_cov=covariance_obs)
    # Priors, parameters
    eta2 = 50
    l2 = 0.3
    v_po ~ MvNormal(zeros(length(X)), ones(length(X)))
    omegam_po ~ omegam_dist
    s8_po ~ s8_dist
    h_po ~ h0_dist
    r_po ~ rd_dist
    M_po ~ M_dist
    
    kernel = sqexp_cov_fn(X, eta=eta2, l=l2)
    cpar = CosmoPar(Ωm=cosmo1.cpar.Ωm, Ωb=cosmo1.cpar.Ωb, h=cosmo1.cpar.h, σ8=s8_po)
    mean_ez = Ez(cpar, X)
    ez_latent = latent_GP(mean_ez, v_po, kernel)
    ez_gp = conditional(X, int_grid, ez_latent, sqexp_cov_fn; eta=eta2, l=l2) # converting from latent space to integral space
    
    # sampling over parameters
    hz = hz_from_ez(int_grid, h_po, ez_gp);
    aiso = a_iso(int_grid, h_po, r_po, ez_gp);
    aap = a_ap(int_grid, h_po, ez_gp);
    fs8 = fs8_from_ez(int_grid, omegam_po, s8_po, h_po, ez_gp, eltype(ez_gp));
    mu_mod = mu(int_grid, h_po, M_po, ez_gp);

    hz_interp = LinearInterpolation(int_grid, hz, extrapolation_bc=Line())
    aiso_interp = LinearInterpolation(int_grid, aiso, extrapolation_bc=Line())
    aap_interp = LinearInterpolation(int_grid, aap, extrapolation_bc=Line())
    fs8_interp = LinearInterpolation(int_grid, fs8, extrapolation_bc=Line())
    mu_interp = LinearInterpolation(int_grid, mu_mod, extrapolation_bc=Line())

    hdata := hz_interp(fakedatahz.z)
    aisodata := aiso_interp(fakedataaiso.z)
    aapdata := aap_interp(fakedataaap.z)
    fs8data := fs8_interp(fakedatafs8.z)
    mudata := mu_interp(fakedatamu.z)
   

    datay = [hdata;aisodata;aapdata;fs8data;mudata]

    y ~ MvNormal(datay, data_cov) 

end
# Out:
# stats_model (generic function with 2 methods)

# %%
chain_gp = sample(stats_model(data_obs), NUTS(10, 0.7), 50)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 3.4694469519536144e-19
# └ @ Turing.Inference /Users/vis/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:212
# Sampling   2%|▊                                         |  ETA: 0:26:53
# Sampling   3%|█▍                                        |  ETA: 0:13:34
# Sampling   5%|██▏                                       |  ETA: 0:10:31
# Sampling   7%|██▊                                       |  ETA: 0:12:37
# Sampling   8%|███▌                                      |  ETA: 0:25:04
# Sampling  10%|████▎                                     |  ETA: 0:33:00
# Sampling  12%|████▉                                     |  ETA: 0:38:17
# Sampling 100%|██████████████████████████████████████████| Time: 0:05:41
# InterruptException:
#
#
#
# Stacktrace:
#
#   [1] Array
#
#     @ ./boot.jl:579 [inlined]
#
#   [2] Array
#
#     @ ./boot.jl:591 [inlined]
#
#   [3] Array
#
#     @ ./boot.jl:599 [inlined]
#
#   [4] similar
#
#     @ ./abstractarray.jl:868 [inlined]
#
#   [5] similar
#
#     @ ./abstractarray.jl:867 [inlined]
#
#   [6] similar
#
#     @ ./broadcast.jl:224 [inlined]
#
#   [7] similar
#
#     @ ./broadcast.jl:223 [inlined]
#
#   [8] copy
#
#     @ ./broadcast.jl:897 [inlined]
#
#   [9] materialize
#
#     @ ./broadcast.jl:872 [inlined]
#
#  [10] _block_indices(B::BlockDiagonal{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, Matrix{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}, i::Int64, j::Int64)
#
#     @ BlockDiagonals ~/.julia/packages/BlockDiagonals/lfczO/src/blockdiagonal.jl:173
#
#  [11] setindex!
#
#     @ ~/.julia/packages/BlockDiagonals/lfczO/src/blockdiagonal.jl:134 [inlined]
#
#  [12] _setindex!
#
#     @ ./abstractarray.jl:1443 [inlined]
#
#  [13] setindex!
#
#     @ ./abstractarray.jl:1413 [inlined]
#
#  [14] copyto_unaliased!(deststyle::IndexCartesian, dest::BlockDiagonal{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, Matrix{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}, srcstyle::IndexCartesian, src::BlockDiagonal{Float64, Matrix{Float64}})
#
#     @ Base ./abstractarray.jl:1095
#
#  [15] copyto!
#
#     @ ./abstractarray.jl:1061 [inlined]
#
#  [16] copyto_axcheck!(dest::BlockDiagonal{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, Matrix{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}, src::BlockDiagonal{Float64, Matrix{Float64}})
#
#     @ Base ./abstractarray.jl:1167
#
#  [17] AbstractArray
#
#     @ ./array.jl:627 [inlined]
#
#  [18] convert
#
#     @ ./abstractarray.jl:18 [inlined]
#
#  [19] (Cholesky{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}})(C::Cholesky{Float64, BlockDiagonal{Float64, Matrix{Float64}}})
#
#     @ LinearAlgebra /opt/homebrew/Cellar/julia/1.11.7_1/share/julia/stdlib/v1.11/LinearAlgebra/src/cholesky.jl:487
#
#  [20] convert
#
#     @ /opt/homebrew/Cellar/julia/1.11.7_1/share/julia/stdlib/v1.11/LinearAlgebra/src/factorization.jl:102 [inlined]
#
#  [21] PDMat
#
#     @ ~/.julia/packages/PDMats/cb4LS/src/pdmat.jl:19 [inlined]
#
#  [22] PDMat
#
#     @ ~/.julia/packages/PDMats/cb4LS/src/pdmat.jl:28 [inlined]
#
#  [23] convert
#
#     @ ~/.julia/packages/PDMats/cb4LS/src/pdmat.jl:66 [inlined]
#
#  [24] convert
#
#     @ ~/.julia/packages/PDMats/cb4LS/src/pdmat.jl:69 [inlined]
#
#  [25] convert
#
#     @ ~/.julia/packages/PDMats/cb4LS/src/generics.jl:8 [inlined]
#
#  [26] convert
#
#     @ ~/.julia/packages/PDMats/cb4LS/src/generics.jl:9 [inlined]
#
#  [27] MvNormal
#
#     @ ~/.julia/packages/Distributions/psM3H/src/multivariate/mvnormal.jl:188 [inlined]
#
#  [28] MvNormal(μ::Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Σ::BlockDiagonal{Float64, Matrix{Float64}})
#
#     @ Distributions ~/.julia/packages/Distributions/psM3H/src/multivariate/mvnormal.jl:197
#
#  [29] macro expansion
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/compiler.jl:579 [inlined]
#
#  [30] stats_model(__model__::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, __varinfo__::DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Vector{Set{DynamicPPL.Selector}}}}, ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, __context__::DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}, y::Vector{Float64}; int_grid::Vector{Float64}, X::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, data_x::Vector{Float64}, data_cov::BlockDiagonal{Float64, Matrix{Float64}})
#
#     @ Main ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X46sZmlsZQ==.jl:40
#
#  [31] stats_model
#
#     @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X46sZmlsZQ==.jl:1 [inlined]
#
#  [32] _evaluate!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:973 [inlined]
#
#  [33] evaluate_threadunsafe!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:946 [inlined]
#
#  [34] evaluate!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:894 [inlined]
#
#  [35] logdensity(f::LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, θ::Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}})
#
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/MjWTB/src/logdensityfunction.jl:140
#
#  [36] Fix1
#
#     @ ./operators.jl:1127 [inlined]
#
#  [37] chunk_mode_gradient!(result::DiffResults.MutableDiffResult{1, Float64, Tuple{Vector{Float64}}}, f::Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}}, x::Vector{Float64}, cfg::ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}})
#
#     @ ForwardDiff ~/.julia/packages/ForwardDiff/X74OO/src/gradient.jl:141
#
#  [38] gradient!
#
#     @ ~/.julia/packages/ForwardDiff/X74OO/src/gradient.jl:41 [inlined]
#
#  [39] gradient!
#
#     @ ~/.julia/packages/ForwardDiff/X74OO/src/gradient.jl:36 [inlined]
#
#  [40] logdensity_and_gradient
#
#     @ ~/.julia/packages/LogDensityProblemsAD/rBlLq/ext/LogDensityProblemsADForwardDiffExt.jl:118 [inlined]
#
#  [41] ∂logπ∂θ
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:180 [inlined]
#
#  [42] ∂H∂θ
#
#     @ ~/.julia/packages/AdvancedHMC/9NhHg/src/hamiltonian.jl:38 [inlined]
#
#  [43] step(lf::AdvancedHMC.Leapfrog{Float64}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{10}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepR ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/integrator.jl:229
#
#  [44] step
#
#     @ ~/.julia/packages/AdvancedHMC/9NhHg/src/integrator.jl:199 [inlined]
#
#  [45] build_tree(rng::Random.TaskLocalRNG, nt::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{10}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Mod ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:639
#
#  [46] build_tree(rng::Random.TaskLocalRNG, nt::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{10}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Mod ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:649
#
#  [47] build_tree(rng::Random.TaskLocalRNG, nt::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{10}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Mod ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:654
#
# --- the above 2 lines are repeated 1 more time ---
#
#  [50] build_tree(rng::Random.TaskLocalRNG, nt::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{10}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Mod ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:649
#
#  [51] build_tree(rng::Random.TaskLocalRNG, nt::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{10}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Mod ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:654
#
#  [52] transition(rng::Random.TaskLocalRNG, τ::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{10}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Mode ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:703
#
#  [53] transition
#
#     @ ~/.julia/packages/AdvancedHMC/9NhHg/src/sampler.jl:59 [inlined]
#
#  [54] step(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, spl::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, state::Turing.Inference.HMCState{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, AdvancedHMC.HMCKernel{AdvancedHMC.FullMomentumRefreshment, AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}}, AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, M_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:M_po, typeof(identity)}, Int64}, Vector{Normal{Float64}}, Vector{AbstractPPL.VarName{:M_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwa ...
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:261
#
#  [55] macro expansion
#
#     @ ~/.julia/packages/AbstractMCMC/1gucv/src/sample.jl:0 [inlined]
#
#  [56] (::AbstractMCMC.var"#29#30"{Nothing, Int64, Int64, Int64, UnionAll, Nothing, @Kwargs{nadapts::Int64}, Random.TaskLocalRNG, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Float64, Int64, Int64})()
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/1gucv/src/logging.jl:134
#
#  [57] with_logstate(f::AbstractMCMC.var"#29#30"{Nothing, Int64, Int64, Int64, UnionAll, Nothing, @Kwargs{nadapts::Int64}, Random.TaskLocalRNG, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Float64, Int64, Int64}, logstate::Base.CoreLogging.LogState)
#
#     @ Base.CoreLogging ./logging/logging.jl:524
#
#  [58] with_logger(f::Function, logger::LoggingExtras.TeeLogger{Tuple{LoggingExtras.EarlyFilteredLogger{TerminalLoggers.TerminalLogger, AbstractMCMC.var"#1#3"{Module}}, LoggingExtras.EarlyFilteredLogger{Base.CoreLogging.SimpleLogger, AbstractMCMC.var"#2#4"{Module}}}})
#
#     @ Base.CoreLogging ./logging/logging.jl:635
#
#  [59] with_progresslogger(f::Function, _module::Module, logger::Base.CoreLogging.SimpleLogger)
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/1gucv/src/logging.jl:157
#
#  [60] macro expansion
#
#     @ ~/.julia/packages/AbstractMCMC/1gucv/src/logging.jl:133 [inlined]
#
#  [61] mcmcsample(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; progress::Bool, progressname::String, callback::Nothing, num_warmup::Int64, discard_initial::Int64, thinning::Int64, chain_type::Type, initial_state::Nothing, kwargs::@Kwargs{nadapts::Int64})
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/1gucv/src/sample.jl:168
#
#  [62] sample(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; chain_type::Type, resume_from::Nothing, initial_state::Nothing, progress::Bool, nadapts::Int64, discard_adapt::Bool, discard_initial::Int64, kwargs::@Kwargs{})
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:123
#
#  [63] sample
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:92 [inlined]
#
#  [64] #sample#4
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:276 [inlined]
#
#  [65] sample
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:267 [inlined]
#
#  [66] #sample#3
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:264 [inlined]
#
#  [67] sample(model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, alg::NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}, N::Int64)
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:258
#
#  [68] eval
#
#     @ ./boot.jl:430 [inlined]
#
#  [69] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base ./loading.jl:2734
#
#  [70] #invokelatest#2
#
#     @ ./essentials.jl:1055 [inlined]
#
#  [71] invokelatest
#
#     @ ./essentials.jl:1052 [inlined]
#
#  [72] (::VSCodeServer.var"#220#221"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.176.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:24
#
#  [73] withpath(f::VSCodeServer.var"#220#221"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.176.2/scripts/packages/VSCodeServer/src/repl.jl:303
#
#  [74] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.176.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:13
#
#  [75] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#
#     @ VSCodeServer.JSONRPC ~/.vscode/extensions/julialang.language-julia-1.176.2/scripts/packages/JSONRPC/src/typed.jl:68
#
#  [76] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#9#14"{String})
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.176.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:147

# %%
# data posterior gp chains
hdata_p = group(chain_gp, :hdata).value.data[:,:,1];
aisodata_p = group(chain_gp, :aisodata).value.data[:,:,1];
aapdata_p =  group(chain_gp, :aapdata).value.data[:,:,1];
fs8data_p =  group(chain_gp, :fs8data).value.data[:,:,1];
mudata_p =  group(chain_gp, :mudata).value.data[:,:,1];

# parameter chains
v_p = group(chain_gp, :v_po).value.data[:, :, 1];
omegam_p = group(chain_gp, :omegam_po).value.data[:, :, 1];
s8_p = group(chain_gp, :s8_po).value.data[:, :, 1];
# Out:
# UndefVarError: `chain_gp` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X51sZmlsZQ==.jl:1

# %%
# data mean / standard dev.
hpmean, hps = mean(hdata_p, dims=1), std(hdata_p, dims=1);
aisopmean, aisops = mean(aisodata_p, dims=1), std(aisodata_p, dims=1);
aappmean, aapps = mean(aapdata_p, dims=1), std(aapdata_p, dims=1);
fs8pmean, fs8ps = mean(fs8data_p, dims=1), std(fs8data_p, dims=1);
mupmean, mups = mean(mudata_p, dims=1), std(mudata_p, dims=1);
# Out:
# UndefVarError: `hdata_p` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X52sZmlsZQ==.jl:1

# %%
plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, label="Data hz", ms=2, seriestype=:scatter)
plot!(fakedatahz.z, vec(hpmean), label="hz GP mean")
plot!(fakedatahz.z, vec(hpmean .- hps),  fillrange = vec(hpmean .+ hps), fillalpha=0.2, c=4, label="hz standard deviation")
plot!(fakedatahz.z, vec(hz2_lcdm_m), label=" H(z) LCDM mean")
plot!(fakedatahz.z, vec(hz2_lcdm_m .- hz2_lcdm_s),  fillrange = vec(hz2_lcdm_m .+ hz2_lcdm_s), fillalpha=0.2, c=1, label="H(z) LCDM standard deviation")
# Out:
# UndefVarError: `hpmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X53sZmlsZQ==.jl:2

# %%
plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, label="Data a_iso", ms=2, seriestype=:scatter)
plot!(fakedataaiso.z, vec(aisopmean), label="a_iso GP mean")
plot!(fakedataaiso.z, vec(aisopmean .- aisops),  fillrange = vec(aisopmean .+ aisops), fillalpha=0.2, c=1, label="a_iso standard deviation")
# Out:
# UndefVarError: `aisopmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X54sZmlsZQ==.jl:2

# %%
plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, label="Data a_ap", ms=2, seriestype=:scatter)
plot!(fakedataaap.z, vec(aappmean), label="a_ap mean")
plot!(fakedataaap.z, vec(aappmean .- aapps),  fillrange = vec(aappmean .+ aapps), fillalpha=0.2, c=1, label="a_ap standard deviation")
# Out:
# UndefVarError: `aappmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X55sZmlsZQ==.jl:2

# %%
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(fakedatafs8.z, vec(fs8pmean), label="fs8 mean")
plot!(fakedatafs8.z, vec(fs8pmean .- fs8ps),  fillrange = vec(fs8pmean .+ fs8ps), fillalpha=0.2, c=1, label="fs8 standard deviation")
# Out:
# UndefVarError: `fs8pmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X56sZmlsZQ==.jl:2

# %%
plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(fakedatafs8.z, vec(fs8pmean), label="fs8 mean")
plot!(fakedatafs8.z, vec(fs8pmean .- fs8ps),  fillrange = vec(fs8pmean .+ fs8ps), fillalpha=0.2, c=1, label="fs8 gp standard deviation")
plot!(z_integ1, vec(fs8_lcdm_m), label="fs8 lcdm")
plot!(z_integ1, vec(fs8_lcdm_m .- fs8_lcdm_s),  fillrange = vec(fs8_lcdm_m .+ fs8_lcdm_s), fillalpha=0.2, c=4, label="fs8 lcdm standard deviation")
# Out:
# UndefVarError: `fs8pmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X60sZmlsZQ==.jl:2

# %%
plot(fakedatamu.z, fakedatamu.data, yerr=mu_err, label="Data mu", ms=2, seriestype=:scatter)
plot!(fakedatamu.z, vec(mupmean), label="mu mean")
plot!(fakedatamu.z, vec(mupmean .- mups),  fillrange = vec(mupmean .+ mups), fillalpha=0.2, c=1, label="mu standard deviation")
# Out:
# UndefVarError: `mupmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X61sZmlsZQ==.jl:2

# %%
p0 = plot(fakedatahz.z, fakedatahz.data, yerr=hz_err, seriestype=:scatter,label="H(z)")
p1 = plot(fakedataaiso.z, fakedataaiso.data, yerr=aiso_err, seriestype=:scatter,label="aiso(z)")
p2 = plot(fakedataaap.z, fakedataaap.data, yerr=aap_err, seriestype=:scatter, label="aap(z)")
p3 = plot(fakedatafs8.z, fakedatafs8.data, yerr=fs8_err, seriestype=:scatter, label="fs8(z)")
p4 = plot(fakedatamu.z, fakedatamu.data, yerr=mu_err, seriestype=:scatter, label="mu(z)")


plot!(p0, fakedatahz.z, vec(hpmean), label="hz GP mean")
plot!(p0, fakedatahz.z, vec(hpmean .- hps),  fillrange = vec(hpmean .+ hps), fillalpha=0.2, c=4, label="H(z) GP standard deviation")
plot!(p0, z_integ1, vec(hz_lcdm_m), label="H(z) LCDM mean")
plot!(p0, z_integ1, vec(hz_lcdm_m .- hz_lcdm_s),  fillrange = vec(hz_lcdm_m .+ hz_lcdm_s), fillalpha=0.2, c=1, label="H(z) LCDM standard deviation")


plot!(p1, fakedataaiso.z, vec(aisopmean), label="a_iso GP mean")
plot!(p1, fakedataaiso.z, vec(aisopmean .- aisops),  fillrange = vec(aisopmean .+ aisops), fillalpha=0.2, c=4, label="a_iso GP standard deviation")
plot!(p1, z_integ1, vec(aiso_lcdm_m), label="a_iso LCDM mean")
plot!(p1, z_integ1, vec(aiso_lcdm_m .- aiso_lcdm_s),  fillrange = vec(aiso_lcdm_m .+ aiso_lcdm_s), fillalpha=0.2, c=1, label="a_iso LCDM standard deviation")


plot!(p2, fakedataaap.z, vec(aappmean), label="a_ap GP mean")
plot!(p2, fakedataaap.z, vec(aappmean .- aapps),  fillrange = vec(aappmean .+ aapps), fillalpha=0.2, c=4, label="a_ap GP standard deviation")
plot!(p2, z_integ1, vec(aap_lcdm_m), label="a_ap LCDM mean")
plot!(p2, z_integ1, vec(aap_lcdm_m .- aap_lcdm_s),  fillrange = vec(aap_lcdm_m .+ aap_lcdm_s), fillalpha=0.2, c=1, label="a_ap LCDM standard deviation")


plot!(p3, fakedatafs8.z, vec(fs8pmean), label="fs8 GP mean")
plot!(p3, fakedatafs8.z, vec(fs8pmean .- fs8ps),  fillrange = vec(fs8pmean .+ fs8ps), fillalpha=0.2, c=4, label="fs8 GP standard deviation")
plot!(p3, z_integ1, vec(fs8_lcdm_m), label="fs8 LCDM mean")
plot!(p3, z_integ1, vec(fs8_lcdm_m .- fs8_lcdm_s),  fillrange = vec(fs8_lcdm_m .+ fs8_lcdm_s), fillalpha=0.2, c=1, label="fs8 LCDM standard deviation")


plot!(p4, fakedatamu.z, vec(mupmean), label="mu GP mean")
plot!(p4, fakedatamu.z, vec(mupmean .- mups),  fillrange = vec(mupmean .+ mups), fillalpha=0.2, c=4, label="mu GP standard deviation")
plot!(p4, z_integ1, vec(mu_lcdm_m), label="mu LCDM mean")
plot!(p4, z_integ1, vec(mu_lcdm_m .- mu_lcdm_s),  fillrange = vec(mu_lcdm_m .+ mu_lcdm_s), fillalpha=0.2, c=1, label="mu LCDM standard deviation")

plot(p0, p1, p2, p3, p4, layout=(2,3), size=(1600,1000))
# Out:
# UndefVarError: `hpmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X62sZmlsZQ==.jl:8
