# %% [markdown]
# # Setting up a latent function Gaussian Process
#
# Let us start by importing Turing.jl, the library we will use to write our statistical model and our GaussianProcess.jl package. \
# The rest of the imports will only be used to generate the data and plot.

# %%
using Turing
using Distances
using LinearAlgebra
using LimberJack
# Out:
#     CondaPkg Found dependencies: /Users/vis/.julia/packages/CondaPkg/0UqYV/CondaPkg.toml
#     CondaPkg Found dependencies: /Users/vis/.julia/packages/PythonCall/mkWc2/CondaPkg.toml
#     CondaPkg Found dependencies: /Users/vis/.julia/packages/IJulia/y8YGF/CondaPkg.toml
#     CondaPkg Initialising pixi
#              │ /Users/vis/.julia/artifacts/d2fecc2a9fa3eac2108d3e4d9d155e6ff5dfd0b2/bin/pixi
#              │ init
#              │ --format pixi
#              └ /Users/vis/Desktop/Cosmography_GP/.CondaPkg
# ✔ Created /Users/vis/Desktop/Cosmography_GP/.CondaPkg/pixi.toml
#     CondaPkg Wrote /Users/vis/Desktop/Cosmography_GP/.CondaPkg/pixi.toml
#              │ [dependencies]
#              │ openssl = ">=3, <3.6"
#              │ jupyter_kernel_test = "*"
#              │ jupyter_client = "*"
#              │
#              │     [dependencies.python]
#              │     channel = "conda-forge"
#              │     build = "*cp*"
#              │     version = ">=3.9,<4"
#              │
#              │ [project]
#              │ name = ".CondaPkg"
#              │ platforms = ["osx-arm64"]
#              │ channels = ["conda-forge"]
#              │ channel-priority = "strict"
#              └ description = "automatically generated by CondaPkg.jl"
#     CondaPkg Installing packages
#              │ /Users/vis/.julia/artifacts/d2fecc2a9fa3eac2108d3e4d9d155e6ff5dfd0b2/bin/pixi
#              │ install
#              └ --manifest-path /Users/vis/Desktop/Cosmography_GP/.CondaPkg/pixi.toml
# ✔ The default environment has been installed.

# %%
using Interpolations
using GaussianProcess
using Plots

# %% [markdown]
# ### 1. Get the Hz data
# This time we will apply a non-linear transformation to our data.

# %%
function CC()
    z = [
        0.07, 0.09, 0.12, 0.17, 0.179, 0.199, 0.2,
        0.27, 0.28, 0.352, 0.38, 0.3802, 0.4,
        0.4004, 0.4247, 0.44, 0.4497, 0.47, 0.4783,
        0.48, 0.51, 0.593, 0.6, 0.61, 0.68, 0.73,
        0.781, 0.875, 0.88, 0.9, 1.037, 1.3,
        1.363, 1.43, 1.53, 1.75, 1.965
    ]

    data = [
        69.0, 69.0, 68.6, 83.0, 75.0, 75.0, 72.9,
        77.0, 88.8, 83.0, 81.5, 83.0, 95.0, 77.0,
        87.1, 82.6, 92.8, 89.0, 80.9, 97.0, 90.4,
        104.0, 87.9, 97.3, 92.0, 97.3, 105.0,
        125.0, 90.0, 117.0, 154.0, 168.0, 160.0,
        177.0, 140.0, 202.0, 186.5
    ]

    err = [
        19.6, 12.0, 26.2, 8.0, 4.0, 5.0, 29.6,
        14.0, 36.6, 14.0, 1.9, 13.5, 17.0, 10.2,
        11.2, 7.8, 12.9, 23.0, 9.0, 62.0, 1.9,
        13.0, 6.1, 2.1, 8.0, 7.0, 12.0, 17.0,
        40.0, 23.0, 20.0, 17.0, 33.6, 18.0,
        14.0, 40.0, 50.4
    ]

    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end

    return (
        data_name = "CC",
        z = z,
        data = data,
        cov = cov
    )
end
# Out:
# CC (generic function with 1 method)

# %%
function BOSSDR12()
    z = [0.38, 0.51, 0.61]
    data = [81.2087, 90.9029, 98.9647]
    cov = [5.00049e+02 2.94536e+02 1.42011e+02; 2.94536e+02 7.02299e+02 4.32750e+02; 1.42011e+02 4.32750e+02 1.01718e+03]
    return (data_name = "BOSSDR12", z = z, data = data, cov = cov)
end
# Out:
# BOSSDR12 (generic function with 1 method)

# %%
cc = CC();
bossdr12 = BOSSDR12();

# %%
hubble_data  = [bossdr12.data; cc.data];
zh = [bossdr12.z; cc.z];

# %%
covariance = zeros(length(bossdr12.data)+ length(cc.data), length(bossdr12.data)+ length(cc.data));
for i in 1:length(bossdr12.data)
    for j in 1:length(bossdr12.data)
        covariance[i,j] = bossdr12.cov[i,j]
    end
end

for i in 1:length(cc.data)
    for j in 1:length(cc.data)
        covariance[i+length(bossdr12.data), j+length(bossdr12.data)] = cc.cov[i,j]
    end
end

# %%
zcont = range(0, 2.5, length=24);
cosmo1 = Cosmology();
H1 = cosmo1.cpar.h*100*Ez(cosmo1, zcont);

# %%
omegam = 0.3
omegab = 0.05
hc = 0.67
# Out:
# 0.67

# %% [markdown]
# ### 2. Check what our priors look like

# %%
function model_latent_GP(eta, l, v;  
                         X=zcont, data_x=zh, data_cov=covariance)
    # Dimensions of predictors .
    kernel = sqexp_cov_fn(X; eta=eta, l=l)
    cpar = CosmoPar(Ωm=omegam,  Ωb=omegab, h=hc)
    mean_hz = cpar.h*100*Ez(cpar, X)
    gp = latent_GP(mean_hz, v, kernel)
    y =  conditional(X, data_x, gp, sqexp_cov_fn;
                     eta=eta, l=l)
    return gp, y
end
# Out:
# model_latent_GP (generic function with 1 method)

# %%
N_samples = 100
gps=zeros(N_samples, 24)
ys=zeros(N_samples, 40)
for i in 1:N_samples
    eta = 200*rand(Uniform(0., 0.1))
    l = 0.02*rand(Uniform(0.1, 3))
    v = rand(MvNormal(zeros(length(zcont)), ones(length(zcont))))
    gps[i, :], ys[i, :] = model_latent_GP(eta, l, v)
end

y_m, y_s = mean(ys, dims=1), std(ys, dims=1);
gp_m, gp_s = mean(gps, dims=1), std(gps, dims=1);

# %%
plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
#plot!(zcont, H1)
plot!(zcont, vec(gp_m), label="GP mean")
plot!(zcont, vec(gp_m .- gp_s),  fillrange = vec(gp_m .+ gp_s), fillalpha=0.2, c=1, label="GP standard deviation")

# %%
plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
#plot!(zcont, H1)
plot!(zh, vec(y_m), label="y mean")
plot!(zh, vec(y_m .- y_s),  fillrange = vec(y_m .+ y_s), fillalpha=0.2, c=1, label="y standard deviation")

# %% [markdown]
# ### 3. Define our statistical model

# %%
@model function stats_model(y; X=zcont, data_x=zh, data_cov=covariance)
    # Priors.
    eta ~ 200*Uniform(0.0, 0.1)
    l ~ 0.02*Uniform(0.1, 3)
    v ~ MvNormal(zeros(length(X)), ones(length(X)))
    kernel = sqexp_cov_fn(X, eta=eta, l=l)
    cpar = CosmoPar(Ωm=omegam,  Ωb=omegab, h=hc)
    mean_hz = cpar.h*100*Ez(cpar, X)
    gp = latent_GP(mean_hz, v, kernel)
    m = conditional(X, data_x, gp, sqexp_cov_fn; eta=eta, l=l)
    y ~ MvNormal(m, data_cov)
end
# Out:
# stats_model (generic function with 2 methods)

# %% [markdown]
# ### 4. Sample the model

# %%
chain = sample(stats_model(hubble_data), NUTS(100, 0.65), 1000)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 1.6
# └ @ Turing.Inference /Users/vis/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:212
# Sampling   1%|▎                                         |  ETA: 0:43:16
# Sampling   1%|▍                                         |  ETA: 0:23:48
# Sampling   2%|▋                                         |  ETA: 0:15:48
# Sampling   2%|▉                                         |  ETA: 0:12:16
# Sampling   3%|█▏                                        |  ETA: 0:09:44
# Sampling   3%|█▎                                        |  ETA: 0:08:19
# Sampling   4%|█▌                                        |  ETA: 0:07:03
# Sampling   4%|█▋                                        |  ETA: 0:06:19
# Sampling   5%|█▉                                        |  ETA: 0:05:36
# Sampling   5%|██▏                                       |  ETA: 0:05:06
# Sampling   6%|██▍                                       |  ETA: 0:04:37
# Sampling   6%|██▌                                       |  ETA: 0:04:18
# Sampling   7%|██▊                                       |  ETA: 0:03:57
# Sampling   7%|███                                       |  ETA: 0:03:42
# Sampling   8%|███▏                                      |  ETA: 0:03:27
# Sampling   8%|███▍                                      |  ETA: 0:03:17
# Sampling   9%|███▋                                      |  ETA: 0:03:05
# Sampling   9%|███▊                                      |  ETA: 0:02:56
# Sampling  10%|████                                      |  ETA: 0:02:47
# Sampling  10%|████▎                                     |  ETA: 0:02:40
# Sampling  11%|████▍                                     |  ETA: 0:02:32
# Sampling  11%|████▋                                     |  ETA: 0:02:26
# Sampling  12%|████▉                                     |  ETA: 0:02:19
# Sampling  12%|█████                                     |  ETA: 0:02:14
# Sampling  13%|█████▎                                    |  ETA: 0:02:08
# Sampling  13%|█████▌                                    |  ETA: 0:02:04
# Sampling  14%|█████▊                                    |  ETA: 0:01:59
# Sampling  14%|█████▉                                    |  ETA: 0:01:55
# Sampling  15%|██████▏                                   |  ETA: 0:01:50
# Sampling  15%|██████▎                                   |  ETA: 0:01:47
# Sampling  16%|██████▌                                   |  ETA: 0:01:43
# Sampling  16%|██████▊                                   |  ETA: 0:01:40
# Sampling  17%|███████                                   |  ETA: 0:01:37
# Sampling  17%|███████▏                                  |  ETA: 0:01:34
# Sampling  18%|███████▍                                  |  ETA: 0:01:31
# Sampling  18%|███████▌                                  |  ETA: 0:01:29
# Sampling  19%|███████▊                                  |  ETA: 0:01:26
# Sampling  19%|████████                                  |  ETA: 0:01:24
# Sampling  20%|████████▎                                 |  ETA: 0:01:22
# Sampling  20%|████████▍                                 |  ETA: 0:01:20
# Sampling  21%|████████▋                                 |  ETA: 0:01:18
# Sampling  21%|████████▉                                 |  ETA: 0:01:16
# Sampling  22%|█████████                                 |  ETA: 0:01:14
# Sampling  22%|█████████▎                                |  ETA: 0:01:12
# Sampling  23%|█████████▌                                |  ETA: 0:01:10
# Sampling  23%|█████████▋                                |  ETA: 0:01:09
# Sampling  24%|█████████▉                                |  ETA: 0:01:07
# Sampling  24%|██████████▏                               |  ETA: 0:01:06
# Sampling  25%|██████████▎                               |  ETA: 0:01:04
# Sampling  25%|██████████▌                               |  ETA: 0:01:03
# Sampling  26%|██████████▊                               |  ETA: 0:01:01
# Sampling  26%|██████████▉                               |  ETA: 0:01:00
# Sampling  27%|███████████▏                              |  ETA: 0:00:59
# Sampling  27%|███████████▍                              |  ETA: 0:00:58
# Sampling  28%|███████████▋                              |  ETA: 0:00:57
# Sampling  28%|███████████▊                              |  ETA: 0:00:56
# Sampling  29%|████████████                              |  ETA: 0:00:54
# Sampling  29%|████████████▏                             |  ETA: 0:00:53
# Sampling  30%|████████████▍                             |  ETA: 0:00:52
# Sampling  30%|████████████▋                             |  ETA: 0:00:51
# Sampling  31%|████████████▉                             |  ETA: 0:00:50
# Sampling  31%|█████████████                             |  ETA: 0:00:49
# Sampling  32%|█████████████▎                            |  ETA: 0:00:48
# Sampling  32%|█████████████▌                            |  ETA: 0:00:48
# Sampling  33%|█████████████▋                            |  ETA: 0:00:47
# Sampling  33%|█████████████▉                            |  ETA: 0:00:46
# Sampling  34%|██████████████▏                           |  ETA: 0:00:45
# Sampling  34%|██████████████▎                           |  ETA: 0:00:44
# Sampling  35%|██████████████▌                           |  ETA: 0:00:43
# Sampling  35%|██████████████▊                           |  ETA: 0:00:43
# Sampling  36%|██████████████▉                           |  ETA: 0:00:42
# Sampling  36%|███████████████▏                          |  ETA: 0:00:41
# Sampling  37%|███████████████▍                          |  ETA: 0:00:41
# Sampling  37%|███████████████▌                          |  ETA: 0:00:40
# Sampling  38%|███████████████▊                          |  ETA: 0:00:39
# Sampling  38%|████████████████                          |  ETA: 0:00:39
# Sampling  39%|████████████████▎                         |  ETA: 0:00:38
# Sampling  39%|████████████████▍                         |  ETA: 0:00:37
# Sampling  40%|████████████████▋                         |  ETA: 0:00:37
# Sampling  40%|████████████████▊                         |  ETA: 0:00:36
# Sampling  41%|█████████████████                         |  ETA: 0:00:35
# Sampling  41%|█████████████████▎                        |  ETA: 0:00:35
# Sampling  42%|█████████████████▌                        |  ETA: 0:00:34
# Sampling  42%|█████████████████▋                        |  ETA: 0:00:34
# Sampling  43%|█████████████████▉                        |  ETA: 0:00:33
# Sampling  43%|██████████████████                        |  ETA: 0:00:33
# Sampling  44%|██████████████████▎                       |  ETA: 0:00:32
# Sampling  44%|██████████████████▌                       |  ETA: 0:00:32
# Sampling  45%|██████████████████▊                       |  ETA: 0:00:31
# Sampling  45%|██████████████████▉                       |  ETA: 0:00:31
# Sampling  46%|███████████████████▏                      |  ETA: 0:00:30
# Sampling  46%|███████████████████▍                      |  ETA: 0:00:30
# Sampling  47%|███████████████████▌                      |  ETA: 0:00:29
# Sampling  47%|███████████████████▊                      |  ETA: 0:00:29
# Sampling  48%|████████████████████                      |  ETA: 0:00:28
# Sampling  48%|████████████████████▏                     |  ETA: 0:00:28
# Sampling  49%|████████████████████▍                     |  ETA: 0:00:27
# Sampling  49%|████████████████████▋                     |  ETA: 0:00:27
# Sampling  50%|████████████████████▊                     |  ETA: 0:00:27
# Sampling  50%|█████████████████████                     |  ETA: 0:00:26
# Sampling  51%|█████████████████████▎                    |  ETA: 0:00:26
# Sampling  51%|█████████████████████▍                    |  ETA: 0:00:25
# Sampling  52%|█████████████████████▋                    |  ETA: 0:00:25
# Sampling  52%|█████████████████████▉                    |  ETA: 0:00:25
# Sampling  53%|██████████████████████▏                   |  ETA: 0:00:24
# Sampling  53%|██████████████████████▎                   |  ETA: 0:00:24
# Sampling  54%|██████████████████████▌                   |  ETA: 0:00:23
# Sampling  54%|██████████████████████▋                   |  ETA: 0:00:23
# Sampling  55%|██████████████████████▉                   |  ETA: 0:00:23
# Sampling  55%|███████████████████████▏                  |  ETA: 0:00:22
# Sampling  56%|███████████████████████▍                  |  ETA: 0:00:22
# Sampling  56%|███████████████████████▌                  |  ETA: 0:00:22
# Sampling  57%|███████████████████████▊                  |  ETA: 0:00:21
# Sampling  57%|████████████████████████                  |  ETA: 0:00:21
# Sampling  58%|████████████████████████▏                 |  ETA: 0:00:21
# Sampling  58%|████████████████████████▍                 |  ETA: 0:00:20
# Sampling  59%|████████████████████████▋                 |  ETA: 0:00:20
# Sampling  59%|████████████████████████▊                 |  ETA: 0:00:20
# Sampling  60%|█████████████████████████                 |  ETA: 0:00:19
# Sampling  60%|█████████████████████████▎                |  ETA: 0:00:19
# Sampling  61%|█████████████████████████▍                |  ETA: 0:00:19
# Sampling  61%|█████████████████████████▋                |  ETA: 0:00:18
# Sampling  62%|█████████████████████████▉                |  ETA: 0:00:18
# Sampling  62%|██████████████████████████                |  ETA: 0:00:18
# Sampling  63%|██████████████████████████▎               |  ETA: 0:00:17
# Sampling  63%|██████████████████████████▌               |  ETA: 0:00:17
# Sampling  64%|██████████████████████████▊               |  ETA: 0:00:17
# Sampling  64%|██████████████████████████▉               |  ETA: 0:00:16
# Sampling  65%|███████████████████████████▏              |  ETA: 0:00:16
# Sampling  65%|███████████████████████████▎              |  ETA: 0:00:16
# Sampling  66%|███████████████████████████▌              |  ETA: 0:00:15
# Sampling  66%|███████████████████████████▊              |  ETA: 0:00:15
# Sampling  67%|████████████████████████████              |  ETA: 0:00:15
# Sampling  67%|████████████████████████████▏             |  ETA: 0:00:15
# Sampling  68%|████████████████████████████▍             |  ETA: 0:00:14
# Sampling  68%|████████████████████████████▌             |  ETA: 0:00:14
# Sampling  69%|████████████████████████████▊             |  ETA: 0:00:14
# Sampling  69%|█████████████████████████████             |  ETA: 0:00:14
# Sampling  70%|█████████████████████████████▎            |  ETA: 0:00:13
# Sampling  70%|█████████████████████████████▍            |  ETA: 0:00:13
# Sampling  71%|█████████████████████████████▋            |  ETA: 0:00:13
# Sampling  71%|█████████████████████████████▉            |  ETA: 0:00:13
# Sampling  72%|██████████████████████████████            |  ETA: 0:00:12
# Sampling  72%|██████████████████████████████▎           |  ETA: 0:00:12
# Sampling  73%|██████████████████████████████▌           |  ETA: 0:00:12
# Sampling  73%|██████████████████████████████▋           |  ETA: 0:00:11
# Sampling  74%|██████████████████████████████▉           |  ETA: 0:00:11
# Sampling  74%|███████████████████████████████▏          |  ETA: 0:00:11
# Sampling  75%|███████████████████████████████▎          |  ETA: 0:00:11
# Sampling  75%|███████████████████████████████▌          |  ETA: 0:00:10
# Sampling  76%|███████████████████████████████▊          |  ETA: 0:00:10
# Sampling  76%|███████████████████████████████▉          |  ETA: 0:00:10
# Sampling  77%|████████████████████████████████▏         |  ETA: 0:00:10
# Sampling  77%|████████████████████████████████▍         |  ETA: 0:00:10
# Sampling  78%|████████████████████████████████▋         |  ETA: 0:00:09
# Sampling  78%|████████████████████████████████▊         |  ETA: 0:00:09
# Sampling  79%|█████████████████████████████████         |  ETA: 0:00:09
# Sampling  79%|█████████████████████████████████▏        |  ETA: 0:00:09
# Sampling  80%|█████████████████████████████████▍        |  ETA: 0:00:08
# Sampling  80%|█████████████████████████████████▋        |  ETA: 0:00:08
# Sampling  81%|█████████████████████████████████▉        |  ETA: 0:00:08
# Sampling  81%|██████████████████████████████████        |  ETA: 0:00:08
# Sampling  82%|██████████████████████████████████▎       |  ETA: 0:00:07
# Sampling  82%|██████████████████████████████████▌       |  ETA: 0:00:07
# Sampling  83%|██████████████████████████████████▋       |  ETA: 0:00:07
# Sampling  83%|██████████████████████████████████▉       |  ETA: 0:00:07
# Sampling  84%|███████████████████████████████████▏      |  ETA: 0:00:07
# Sampling  84%|███████████████████████████████████▎      |  ETA: 0:00:06
# Sampling  85%|███████████████████████████████████▌      |  ETA: 0:00:06
# Sampling  85%|███████████████████████████████████▊      |  ETA: 0:00:06
# Sampling  86%|███████████████████████████████████▉      |  ETA: 0:00:06
# Sampling  86%|████████████████████████████████████▏     |  ETA: 0:00:05
# Sampling  87%|████████████████████████████████████▍     |  ETA: 0:00:05
# Sampling  87%|████████████████████████████████████▌     |  ETA: 0:00:05
# Sampling  88%|████████████████████████████████████▊     |  ETA: 0:00:05
# Sampling  88%|█████████████████████████████████████     |  ETA: 0:00:05
# Sampling  89%|█████████████████████████████████████▎    |  ETA: 0:00:04
# Sampling  89%|█████████████████████████████████████▍    |  ETA: 0:00:04
# Sampling  90%|█████████████████████████████████████▋    |  ETA: 0:00:04
# Sampling  90%|█████████████████████████████████████▊    |  ETA: 0:00:04
# Sampling  91%|██████████████████████████████████████    |  ETA: 0:00:04
# Sampling  91%|██████████████████████████████████████▎   |  ETA: 0:00:03
# Sampling  92%|██████████████████████████████████████▌   |  ETA: 0:00:03
# Sampling  92%|██████████████████████████████████████▋   |  ETA: 0:00:03
# Sampling  93%|██████████████████████████████████████▉   |  ETA: 0:00:03
# Sampling  93%|███████████████████████████████████████   |  ETA: 0:00:03
# Sampling  94%|███████████████████████████████████████▎  |  ETA: 0:00:02
# Sampling  94%|███████████████████████████████████████▌  |  ETA: 0:00:02
# Sampling  95%|███████████████████████████████████████▊  |  ETA: 0:00:02
# Sampling  95%|███████████████████████████████████████▉  |  ETA: 0:00:02
# Sampling  96%|████████████████████████████████████████▏ |  ETA: 0:00:02
# Sampling  96%|████████████████████████████████████████▍ |  ETA: 0:00:01
# Sampling  97%|████████████████████████████████████████▌ |  ETA: 0:00:01
# Sampling  97%|████████████████████████████████████████▊ |  ETA: 0:00:01
# Sampling  98%|█████████████████████████████████████████ |  ETA: 0:00:01
# Sampling  98%|█████████████████████████████████████████▏|  ETA: 0:00:01
# Sampling  99%|█████████████████████████████████████████▍|  ETA: 0:00:01
# Sampling  99%|█████████████████████████████████████████▋|  ETA: 0:00:00
# Sampling 100%|█████████████████████████████████████████▊|  ETA: 0:00:00
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:36
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:39
# Chains MCMC chain (1000×38×1 Array{Float64, 3}):
#
# Iterations        = 101:1:1100
# Number of chains  = 1
# Samples per chain = 1000
# Wall duration     = 37.69 seconds
# Compute duration  = 37.69 seconds
# parameters        = eta, l, v[1], v[2], v[3], v[4], v[5], v[6], v[7], v[8], v[9], v[10], v[11], v[12], v[13], v[14], v[15], v[16], v[17], v[18], v[19], v[20], v[21], v[22], v[23], v[24]
# internals         = lp, n_steps, is_accept, acceptance_rate, log_density, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size
#
# Summary Statistics
#   parameters      mean       std      mcse    ess_bulk   ess_tail      rhat    ⋯
#       Symbol   Float64   Float64   Float64     Float64    Float64   Float64    ⋯
#
#          eta    7.5611    5.7121    0.4945    140.9738    65.9449    0.9993    ⋯
#            l    0.0340    0.0163    0.0011    257.1457   414.0286    1.0010    ⋯
#         v[1]    0.1805    0.9043    0.0295    941.5960   696.6776    1.0008    ⋯
#         v[2]    0.2475    0.8163    0.0252   1078.6549   641.7513    1.0044    ⋯
#         v[3]    0.0838    0.8369    0.0240   1134.2005   559.2193    0.9994    ⋯
#         v[4]    0.2186    0.7951    0.0235   1108.9685   600.5098    1.0023    ⋯
#         v[5]    0.4150    0.8177    0.0282    866.4635   699.8792    0.9996    ⋯
#         v[6]    0.3340    0.9090    0.0371    609.6872   358.8963    1.0149    ⋯
#         v[7]    0.0744    1.0769    0.0305   1214.9260   425.1191    0.9998    ⋯
#         v[8]    0.1115    0.9585    0.0386    618.2058   424.3015    1.0026    ⋯
#         v[9]    0.1833    0.9505    0.0390    591.6365   435.7355    1.0046    ⋯
#        v[10]    0.1445    1.0069    0.0347    854.5735   429.1755    0.9999    ⋯
#        v[11]    0.1491    1.0242    0.0423    605.1279   239.6355    0.9991    ⋯
#        v[12]    0.1469    1.0159    0.0429    552.3495   470.9034    1.0025    ⋯
#        v[13]    0.1205    1.0152    0.0372    756.2055   678.9875    1.0013    ⋯
#        v[14]   -0.0580    1.0179    0.0328    964.5410   709.9427    1.0002    ⋯
#        v[15]   -0.0641    0.9812    0.0348    808.7005   466.0220    0.9995    ⋯
#       ⋮           ⋮         ⋮         ⋮          ⋮          ⋮          ⋮       ⋱
#                                                      1 column and 9 rows omitted
#
# Quantiles
#   parameters      2.5%     25.0%     50.0%     75.0%     97.5%
#       Symbol   Float64   Float64   Float64   Float64   Float64
#
#          eta    0.3921    2.7160    6.1139   11.5467   19.4628
#            l    0.0048    0.0198    0.0362    0.0483    0.0583
#         v[1]   -1.5230   -0.4168    0.1536    0.7713    2.0503
#         v[2]   -1.2893   -0.3180    0.2288    0.7640    1.8463
#         v[3]   -1.5270   -0.4673    0.0693    0.6101    1.7414
#         v[4]   -1.4967   -0.2896    0.2479    0.6854    1.7829
#         v[5]   -1.1055   -0.1588    0.3575    1.0140    2.0030
#         v[6]   -1.5667   -0.2235    0.3482    0.9410    2.1134
#         v[7]   -2.0372   -0.5977    0.0521    0.7704    2.1654
#         v[8]   -1.7299   -0.4862    0.0860    0.7396    2.0195
#         v[9]   -1.6076   -0.4757    0.1875    0.8553    2.0579
#        v[10]   -1.7426   -0.5998    0.1104    0.8456    2.0297
#        v[11]   -1.6426   -0.5299    0.1052    0.8263    2.2530
#        v[12]   -1.7207   -0.5439    0.0945    0.8277    2.0457
#        v[13]   -1.9047   -0.5300    0.1045    0.7867    1.9610
#        v[14]   -1.9917   -0.6984   -0.0952    0.6128    1.9802
#        v[15]   -1.9842   -0.7598   -0.0489    0.6317    1.8637
#       ⋮           ⋮         ⋮         ⋮         ⋮         ⋮
#                                                   9 rows omitted

# %% [markdown]
# ### 5. Check how our posteriors look like

# %%
eta_p = group(chain, :eta).value.data[:, :, 1];
l_p = group(chain, :l).value.data[:, :, 1];
v_p = group(chain, :v).value.data[:, :, 1];

# %%
println(length(v_p))
# Out:
# 24000

# %%
N_samples2 = length(eta_p)
gps2=zeros(N_samples2, 24)
ys2=zeros(N_samples2, 100)
for i in 1:N_samples2
    gps2[i, :], ys2[i, :] = model_latent_GP(eta_p[i], l_p[i], v_p[i, :];
                                                data_x=LinRange(0, 2.3, 100))
end

y_m2, y_s2 = mean(ys2, dims=1), std(ys2, dims=1);
gp_m2, gp_s2 = mean(gps2, dims=1), std(gps2, dims=1);

# %%
plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
plot!(zcont, H1, label="LCDM", lc=:black)
plot!(LinRange(0, 2.3, 100), vec(y_m2), label="Y mean")
plot!(LinRange(0, 2.3, 100), vec(y_m2 .- y_s2),  fillrange = vec(y_m2 .+ y_s2), fillalpha=0.2, c=1, label="Y standard deviation")

# %%
plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
plot!(zcont, H1, label="LCDM", lc=:black)
plot!(zcont, vec(gp_m2), label="GP mean")
plot!(zcont, vec(gp_m2 .- gp_s2),  fillrange = vec(gp_m2 .+ gp_s2), fillalpha=0.2, c=1, label="GP standard deviation")
