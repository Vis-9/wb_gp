# %% [markdown]
# # Setting up a latent function Gaussian Process
#
# Let us start by importing Turing.jl, the library we will use to write our statistical model and our GaussianProcess.jl package. \
# The rest of the imports will only be used to generate the data and plot.

# %%
using Turing
using Distances
using LinearAlgebra
using LimberJack
# Out:
#     CondaPkg Found dependencies: /Users/vis/.julia/packages/CondaPkg/0UqYV/CondaPkg.toml
#     CondaPkg Found dependencies: /Users/vis/.julia/packages/PythonCall/mkWc2/CondaPkg.toml
#     CondaPkg Found dependencies: /Users/vis/.julia/packages/IJulia/y8YGF/CondaPkg.toml
#     CondaPkg Initialising pixi
#              │ /Users/vis/.julia/artifacts/d2fecc2a9fa3eac2108d3e4d9d155e6ff5dfd0b2/bin/pixi
#              │ init
#              │ --format pixi
#              └ /Users/vis/Desktop/Cosmography_GP/.CondaPkg
# ✔ Created /Users/vis/Desktop/Cosmography_GP/.CondaPkg/pixi.toml
#     CondaPkg Wrote /Users/vis/Desktop/Cosmography_GP/.CondaPkg/pixi.toml
#              │ [dependencies]
#              │ openssl = ">=3, <3.6"
#              │ jupyter_kernel_test = "*"
#              │ jupyter_client = "*"
#              │
#              │     [dependencies.python]
#              │     channel = "conda-forge"
#              │     build = "*cp*"
#              │     version = ">=3.9,<4"
#              │
#              │ [project]
#              │ name = ".CondaPkg"
#              │ platforms = ["osx-arm64"]
#              │ channels = ["conda-forge"]
#              │ channel-priority = "strict"
#              └ description = "automatically generated by CondaPkg.jl"
#     CondaPkg Installing packages
#              │ /Users/vis/.julia/artifacts/d2fecc2a9fa3eac2108d3e4d9d155e6ff5dfd0b2/bin/pixi
#              │ install
#              └ --manifest-path /Users/vis/Desktop/Cosmography_GP/.CondaPkg/pixi.toml
# ✔ The default environment has been installed.

# %%
using Interpolations
using GaussianProcess
using Plots
using QuadGK

# %% [markdown]
# ### 1. Get the Hz data
# This time we will apply a non-linear transformation to our data.

# %%
function CC()
    z = [
        0.07, 0.09, 0.12, 0.17, 0.179, 0.199, 0.2,
        0.27, 0.28, 0.352, 0.38, 0.3802, 0.4,
        0.4004, 0.4247, 0.44, 0.4497, 0.47, 0.4783,
        0.48, 0.51, 0.593, 0.6, 0.61, 0.68, 0.73,
        0.781, 0.875, 0.88, 0.9, 1.037, 1.3,
        1.363, 1.43, 1.53, 1.75, 1.965
    ]

    data = [
        69.0, 69.0, 68.6, 83.0, 75.0, 75.0, 72.9,
        77.0, 88.8, 83.0, 81.5, 83.0, 95.0, 77.0,
        87.1, 82.6, 92.8, 89.0, 80.9, 97.0, 90.4,
        104.0, 87.9, 97.3, 92.0, 97.3, 105.0,
        125.0, 90.0, 117.0, 154.0, 168.0, 160.0,
        177.0, 140.0, 202.0, 186.5
    ]

    err = [
        19.6, 12.0, 26.2, 8.0, 4.0, 5.0, 29.6,
        14.0, 36.6, 14.0, 1.9, 13.5, 17.0, 10.2,
        11.2, 7.8, 12.9, 23.0, 9.0, 62.0, 1.9,
        13.0, 6.1, 2.1, 8.0, 7.0, 12.0, 17.0,
        40.0, 23.0, 20.0, 17.0, 33.6, 18.0,
        14.0, 40.0, 50.4
    ]

    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end

    return (
        data_name = "CC",
        z = z,
        data = data,
        cov = cov
    )
end
# Out:
# CC (generic function with 1 method)

# %%
function BOSSDR12()
    z = [0.38, 0.51, 0.61]
    data = [81.2087, 90.9029, 98.9647]
    cov = [5.00049e+02 2.94536e+02 1.42011e+02; 2.94536e+02 7.02299e+02 4.32750e+02; 1.42011e+02 4.32750e+02 1.01718e+03]
    return (data_name = "BOSSDR12", z = z, data = data, cov = cov)
end
# Out:
# BOSSDR12 (generic function with 1 method)

# %%
function BOSSDR12_dm()
    z = [0.38, 0.51, 0.61]
    data = [1512.39, 1975.22, 2306.68]
    cov = [3.63049e+00 1.80306e+00 9.19842e-01; 1.80306e+00 3.77146e+00 2.21471e+00; 9.19842e-01 2.21471e+00 4.37982e+00]
    return (data_name = "BOSSDR12_dm", z = z, data = data, cov = cov)
end
# Out:
# BOSSDR12_dm (generic function with 1 method)

# %%
cc = CC();
bossdr12 = BOSSDR12();
bossdr12dm = BOSSDR12_dm();

# %%
hubble_data  = [bossdr12.data; cc.data; bossdr12dm.data];
zh = [bossdr12.z; cc.z; bossdr12dm.z];

# %%
covariance = zeros(length(bossdr12.data)+ length(cc.data)+ length(bossdr12dm.data), 
length(bossdr12.data)+ length(cc.data)+ length(bossdr12dm.data));
for i in 1:length(bossdr12.data)
    for j in 1:length(bossdr12.data)
        covariance[i,j] = bossdr12.cov[i,j]
    end
end

for i in 1:length(cc.data)
    for j in 1:length(cc.data)
        covariance[i+length(bossdr12.data), j+length(bossdr12.data)] = cc.cov[i,j]
    end
end

for i in 1:length(bossdr12dm.data)
    for j in 1:length(bossdr12dm.data)
        covariance[i+length(bossdr12.data)+length(bossdr12dm.data), j+length(bossdr12.data)+length(bossdr12dm.data)] = cc.cov[i,j]
    end
end

# %%
zcont = range(0, 2.5, length=24);
cosmo1 = Cosmology();
H1 = cosmo1.cpar.h*100*Ez(cosmo1, zcont);

# %%
omegam = 0.3
omegab = 0.05
hc = 0.67
# Out:
# 0.67

# %% [markdown]
# ### 2. Check what our priors look like

# %%
function model_latent_GP(eta, l, v;  
                         x=zcont, z=zh, data_cov=covariance)
    # Dimensions of predictors .
    kernel = sqexp_cov_fn(x; eta=eta, l=l)
    cpar = CosmoPar(Ωm=omegam,  Ωb=omegab, h=hc)
    mean_hx = cpar.h*100*Ez(cpar, x)
    hx = latent_GP(mean_hx, v, kernel)
    hz =  conditional(x, z, hx, sqexp_cov_fn;
                     eta=eta, l=l)
    return hx, hz
end
# Out:
# model_latent_GP (generic function with 1 method)

# %%
xx = LinRange(0, 1, 300);

# %%
N_samples = 100
hxs=zeros(N_samples, 24)
hzs=zeros(N_samples, 300)
for i in 1:N_samples
    eta = 200*rand(Uniform(0., 0.1))
    l = 0.02*rand(Uniform(0.1, 3))
    v = rand(MvNormal(zeros(length(zcont)), ones(length(zcont))))
    hxs[i, :], hzs[i, :] = model_latent_GP(eta, l, v; z=xx)
end

y_m, y_s = mean(hzs, dims=1), std(hzs, dims=1);
gp_m, gp_s = mean(hxs, dims=1), std(hxs, dims=1);

hz_itp = linear_interpolation(zs, Vector(y_s), extrapolation_bc=Line())
# Out:
# MethodError: no method matching (Vector)(::Matrix{Float64})
#
# The type `Vector` exists, but no method is defined for this combination of argument types when trying to construct it.
#
#
#
# You might have used a 2d row vector where a 1d column vector was required.
#
# Note the difference between 1d column vector [1,2,3] and 2d row vector [1 2 3].
#
# You can convert to a column vector with the vec() function.
#
#
#
# Closest candidates are:
#
#   (Array{T, N} where T)(::AbstractArray{S, N}) where {S, N}
#
#    @ Core boot.jl:603
#
#   (Vector)(!Matched::UndefInitializer, !Matched::Integer)
#
#    @ Base baseext.jl:32
#
#   (Vector)(!Matched::SparseArrays.CHOLMOD.Dense{T}) where T
#
#    @ SparseArrays /opt/homebrew/Cellar/julia/1.11.7_1/share/julia/stdlib/v1.11/SparseArrays/src/solvers/cholmod.jl:1144
#
#   ...
#
#
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/Cosmography_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X21sZmlsZQ==.jl:14

# %%
function comoving_d(zs, hz_itp nz)
    chis = zeros(Real, nz)
    for i in 1:nz
        zz = zs[i]
        chis[i] = quadgk(z -> 1.0/hz_itp(z), 0.0, zz, rtol=1E-5)[1]
        #chis[i] = quadgk(z -> 1.0/Ez(cpar, z), 0.0, zz, rtol=1E-5)[1]
        #chis[i] *= CLIGHT_HMPC / cpar.h

    end
    chii = linear_interpolation(zs, Vector(chis), extrapolation_bc=Line())
    return chii
end
# Out:
# comoving_d (generic function with 1 method)

# %%
# plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
# plot!(zcont, H1)
# plot!(zcont, vec(gp_m), label="GP mean")
# plot!(zcont, vec(gp_m .- gp_s),  fillrange = vec(gp_m .+ gp_s), fillalpha=0.2, c=1, label="GP standard deviation")

# %%
# plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
# plot!(zcont, H1)
# plot!(zh, vec(y_m), label="y mean")
# plot!(zh, vec(y_m .- y_s),  fillrange = vec(y_m .+ y_s), fillalpha=0.2, c=1, label="y standard deviation")

# %% [markdown]
# ### 3. Define our statistical model

# %%
@model function stats_model(y; X=zcont, data_x=zh, data_cov=covariance)
    # Priors.
    eta ~ 200*Uniform(0.0, 0.1)
    l ~ 0.02*Uniform(0.1, 3)
    v ~ MvNormal(zeros(length(X)), ones(length(X)))
    kernel = sqexp_cov_fn(X, eta=eta, l=l)
    cpar = CosmoPar(Ωm=omegam,  Ωb=omegab, h=hc)
    mean_hz = cpar.h*100*Ez(cpar, X)
    gp = latent_GP(mean_hz, v, kernel)
    m = conditional(X, data_x, gp, sqexp_cov_fn; eta=eta, l=l)
    y ~ MvNormal(m, data_cov)
end
# Out:
# stats_model (generic function with 2 methods)

# %% [markdown]
# ### 4. Sample the model

# %%
chain = sample(stats_model(hubble_data), NUTS(100, 0.65), 1000)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:00
# PosDefException: matrix is not positive definite; Factorization failed.
#
#
#
# Stacktrace:
#
#   [1] checkpositivedefinite
#
#     @ /opt/julia-1.11.5/share/julia/stdlib/v1.11/LinearAlgebra/src/factorization.jl:68 [inlined]
#
#   [2] #cholesky!#163
#
#     @ /opt/julia-1.11.5/share/julia/stdlib/v1.11/LinearAlgebra/src/cholesky.jl:269 [inlined]
#
#   [3] cholesky!
#
#     @ /opt/julia-1.11.5/share/julia/stdlib/v1.11/LinearAlgebra/src/cholesky.jl:267 [inlined]
#
#   [4] #cholesky!#164
#
#     @ /opt/julia-1.11.5/share/julia/stdlib/v1.11/LinearAlgebra/src/cholesky.jl:301 [inlined]
#
#   [5] cholesky! (repeats 2 times)
#
#     @ /opt/julia-1.11.5/share/julia/stdlib/v1.11/LinearAlgebra/src/cholesky.jl:295 [inlined]
#
#   [6] _cholesky
#
#     @ /opt/julia-1.11.5/share/julia/stdlib/v1.11/LinearAlgebra/src/cholesky.jl:411 [inlined]
#
#   [7] cholesky(A::Matrix{Float64}, ::NoPivot; check::Bool)
#
#     @ LinearAlgebra /opt/julia-1.11.5/share/julia/stdlib/v1.11/LinearAlgebra/src/cholesky.jl:401
#
#   [8] cholesky (repeats 2 times)
#
#     @ /opt/julia-1.11.5/share/julia/stdlib/v1.11/LinearAlgebra/src/cholesky.jl:401 [inlined]
#
#   [9] PDMat
#
#     @ ~/.julia/packages/PDMats/cb4LS/src/pdmat.jl:40 [inlined]
#
#  [10] MvNormal(μ::Vector{Float64}, Σ::Matrix{Float64})
#
#     @ Distributions ~/.julia/packages/Distributions/YQSrn/src/multivariate/mvnormal.jl:197
#
#  [11] macro expansion
#
#     @ ~/.julia/packages/DynamicPPL/wJmh4/src/compiler.jl:555 [inlined]
#
#  [12] stats_model(__model__::DynamicPPL.Model{typeof(stats_model), (:y,), (:X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, Matrix{Float64}}, DynamicPPL.DefaultContext}, __varinfo__::DynamicPPL.UntypedVarInfo{DynamicPPL.Metadata{Dict{AbstractPPL.VarName, Int64}, Vector{Distribution}, Vector{AbstractPPL.VarName}, Vector{Real}, Vector{Set{DynamicPPL.Selector}}}, Float64}, __context__::DynamicPPL.SamplingContext{DynamicPPL.SampleFromUniform, DynamicPPL.DefaultContext, Random.TaskLocalRNG}, y::Vector{Float64}; X::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, data_x::Vector{Float64}, data_cov::Matrix{Float64})
#
#     @ Main ~/cosmo_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X26sdnNjb2RlLXJlbW90ZQ==.jl:11
#
#  [13] stats_model
#
#     @ ~/cosmo_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X26sdnNjb2RlLXJlbW90ZQ==.jl:1 [inlined]
#
#  [14] _evaluate!!
#
#     @ ~/.julia/packages/DynamicPPL/wJmh4/src/model.jl:963 [inlined]
#
#  [15] evaluate_threadunsafe!!
#
#     @ ~/.julia/packages/DynamicPPL/wJmh4/src/model.jl:936 [inlined]
#
#  [16] evaluate!!
#
#     @ ~/.julia/packages/DynamicPPL/wJmh4/src/model.jl:889 [inlined]
#
#  [17] evaluate!!(model::DynamicPPL.Model{typeof(stats_model), (:y,), (:X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, Matrix{Float64}}, DynamicPPL.DefaultContext}, rng::Random.TaskLocalRNG, varinfo::DynamicPPL.UntypedVarInfo{DynamicPPL.Metadata{Dict{AbstractPPL.VarName, Int64}, Vector{Distribution}, Vector{AbstractPPL.VarName}, Vector{Real}, Vector{Set{DynamicPPL.Selector}}}, Float64}, sampler::DynamicPPL.SampleFromUniform, context::DynamicPPL.DefaultContext)
#
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/wJmh4/src/model.jl:900
#
#  [18] (::DynamicPPL.Model{typeof(stats_model), (:y,), (:X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, Matrix{Float64}}, DynamicPPL.DefaultContext})(::Random.TaskLocalRNG, ::Vararg{Any})
#
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/wJmh4/src/model.jl:860
#
#  [19] VarInfo
#
#     @ ~/.julia/packages/DynamicPPL/wJmh4/src/varinfo.jl:135 [inlined]
#
#  [20] default_varinfo
#
#     @ ~/.julia/packages/DynamicPPL/wJmh4/src/sampler.jl:80 [inlined]
#
#  [21] default_varinfo
#
#     @ ~/.julia/packages/DynamicPPL/wJmh4/src/sampler.jl:71 [inlined]
#
#  [22] step(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, Matrix{Float64}}, DynamicPPL.DefaultContext}, spl::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}; resume_from::Nothing, init_params::Nothing, kwargs::@Kwargs{nadapts::Int64})
#
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/wJmh4/src/sampler.jl:98
#
#  [23] step
#
#     @ ~/.julia/packages/DynamicPPL/wJmh4/src/sampler.jl:84 [inlined]
#
#  [24] macro expansion
#
#     @ ~/.julia/packages/AbstractMCMC/fWWW0/src/sample.jl:125 [inlined]
#
#  [25] macro expansion
#
#     @ ~/.julia/packages/ProgressLogging/EktJo/src/ProgressLogging.jl:328 [inlined]
#
#  [26] (::AbstractMCMC.var"#21#22"{Bool, String, Nothing, Int64, Int64, @Kwargs{nadapts::Int64}, Random.TaskLocalRNG, DynamicPPL.Model{typeof(stats_model), (:y,), (:X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, Matrix{Float64}}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Int64})()
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/fWWW0/src/logging.jl:12
#
#  [27] with_logstate(f::AbstractMCMC.var"#21#22"{Bool, String, Nothing, Int64, Int64, @Kwargs{nadapts::Int64}, Random.TaskLocalRNG, DynamicPPL.Model{typeof(stats_model), (:y,), (:X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, Matrix{Float64}}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Int64}, logstate::Base.CoreLogging.LogState)
#
#     @ Base.CoreLogging ./logging/logging.jl:522
#
#  [28] with_logger(f::Function, logger::LoggingExtras.TeeLogger{Tuple{LoggingExtras.EarlyFilteredLogger{TerminalLoggers.TerminalLogger, AbstractMCMC.var"#1#3"{Module}}, LoggingExtras.EarlyFilteredLogger{Base.CoreLogging.SimpleLogger, AbstractMCMC.var"#2#4"{Module}}}})
#
#     @ Base.CoreLogging ./logging/logging.jl:632
#
#  [29] with_progresslogger(f::Function, _module::Module, logger::Base.CoreLogging.SimpleLogger)
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/fWWW0/src/logging.jl:36
#
#  [30] macro expansion
#
#     @ ~/.julia/packages/AbstractMCMC/fWWW0/src/logging.jl:11 [inlined]
#
#  [31] mcmcsample(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, Matrix{Float64}}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; progress::Bool, progressname::String, callback::Nothing, discard_initial::Int64, thinning::Int64, chain_type::Type, kwargs::@Kwargs{nadapts::Int64})
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/fWWW0/src/sample.jl:116
#
#  [32] sample(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, Matrix{Float64}}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; chain_type::Type, resume_from::Nothing, progress::Bool, nadapts::Int64, discard_adapt::Bool, discard_initial::Int64, kwargs::@Kwargs{})
#
#     @ Turing.Inference ~/.julia/packages/Turing/wjl7M/src/inference/hmc.jl:121
#
#  [33] sample
#
#     @ ~/.julia/packages/Turing/wjl7M/src/inference/hmc.jl:91 [inlined]
#
#  [34] #sample#3
#
#     @ ~/.julia/packages/Turing/wjl7M/src/inference/Inference.jl:196 [inlined]
#
#  [35] sample
#
#     @ ~/.julia/packages/Turing/wjl7M/src/inference/Inference.jl:189 [inlined]
#
#  [36] #sample#2
#
#     @ ~/.julia/packages/Turing/wjl7M/src/inference/Inference.jl:186 [inlined]
#
#  [37] sample(model::DynamicPPL.Model{typeof(stats_model), (:y,), (:X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, Matrix{Float64}}, DynamicPPL.DefaultContext}, alg::NUTS{Turing.Essential.ForwardDiffAD{0}, (), AdvancedHMC.DiagEuclideanMetric}, N::Int64)
#
#     @ Turing.Inference ~/.julia/packages/Turing/wjl7M/src/inference/Inference.jl:180
#
#  [38] top-level scope
#
#     @ ~/cosmo_GP/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X31sdnNjb2RlLXJlbW90ZQ==.jl:1

# %% [markdown]
# ### 5. Check how our posteriors look like

# %%
eta_p = group(chain, :eta).value.data[:, :, 1];
l_p = group(chain, :l).value.data[:, :, 1];
v_p = group(chain, :v).value.data[:, :, 1];

# %%
println(length(v_p))

# %%
N_samples2 = length(eta_p)
gps2=zeros(N_samples2, 24)
ys2=zeros(N_samples2, 100)
for i in 1:N_samples2
    gps2[i, :], ys2[i, :] = model_latent_GP(eta_p[i], l_p[i], v_p[i, :];
                                                data_x=LinRange(0, 2.3, 100))
end

y_m2, y_s2 = mean(ys2, dims=1), std(ys2, dims=1);
gp_m2, gp_s2 = mean(gps2, dims=1), std(gps2, dims=1);

# %%
println(y_m2)

# %%
plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
plot!(zcont, H1, label="LCDM", lc=:black)
plot!(LinRange(0, 2.3, 100), vec(y_m2), label="Y mean")
plot!(LinRange(0, 2.3, 100), vec(y_m2 .- y_s2),  fillrange = vec(y_m2 .+ y_s2), fillalpha=0.2, c=1, label="Y standard deviation")

# %%
plot(zh, hubble_data, label="Data", ms=2, seriestype=:scatter)
plot!(zcont, H1, label="LCDM", lc=:black)
plot!(zcont, vec(gp_m2), label="GP mean")
plot!(zcont, vec(gp_m2 .- gp_s2),  fillrange = vec(gp_m2 .+ gp_s2), fillalpha=0.2, c=1, label="GP standard deviation")
