# %% [markdown]
# # Setting up a latent function Gaussian Process for H(z)

# %%
# import set 
using Turing
using Distances
using LinearAlgebra
using LimberJack
using Interpolations
using GaussianProcess
using Plots
using QuadGK
using BlockDiagonals
using CSV
using DataFrames
using PrettyTables

# %% [markdown]
# ### Collate data

# %%
# setting a cosmology for the fake data, all fiducial cosmo parameters 
cosmo1 = Cosmology();
rd_fid = 99.0792;

# assumed parameter distributions
omegam_dist = Uniform(0.25, 0.35);
h0_dist = Uniform(0.6, 0.8);
s8_dist = Uniform(0.6, 0.9);
rd_dist = Uniform(90, 110);
M_dist = Normal(-19.3, 0.1);

# %% [markdown]
# #### Generate fake data

# %%
# hz data
function data_hz()
    z = [
        0.07, 0.09, 0.12, 0.17, 0.179, 0.199, 0.2,
        0.27, 0.28, 0.352, 0.38, 0.3802, 0.4,
        0.4004, 0.4247, 0.44, 0.4497, 0.47, 0.4783,
        0.48, 0.51, 0.593, 0.6, 0.61, 0.68, 0.73,
        0.781, 0.875, 0.88, 0.9, 1.037, 1.3,
        1.363, 1.43, 1.53, 1.75, 1.965
    ]

    data = [
        69.0, 69.0, 68.6, 83.0, 75.0, 75.0, 72.9,
        77.0, 88.8, 83.0, 81.5, 83.0, 95.0, 77.0,
        87.1, 82.6, 92.8, 89.0, 80.9, 97.0, 90.4,
        104.0, 87.9, 97.3, 92.0, 97.3, 105.0,
        125.0, 90.0, 117.0, 154.0, 168.0, 160.0,
        177.0, 140.0, 202.0, 186.5
    ]

    err = [
        19.6, 12.0, 26.2, 8.0, 4.0, 5.0, 29.6,
        14.0, 36.6, 14.0, 1.9, 13.5, 17.0, 10.2,
        11.2, 7.8, 12.9, 23.0, 9.0, 62.0, 1.9,
        13.0, 6.1, 2.1, 8.0, 7.0, 12.0, 17.0,
        40.0, 23.0, 20.0, 17.0, 33.6, 18.0,
        14.0, 40.0, 50.4
    ]

    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end

    return (
        data_name = "data_hz",
        z = z,
        data = data,
        err = err,
        cov = cov
    )
end

# fs8 data
function data_fs8()

z  = [0.3, 0.51, 0.71, 0.92, 1.32, 1.49]

data  = [0.37784, 0.515897, 0.48384, 0.422208, 0.37468, 0.435]

fs8_upper = [0.4723, 0.572693, 0.539136, 0.470586, 0.418064, 0.48]
fs8_lower = [0.28338, 0.449635, 0.428544, 0.378228, 0.343128, 0.39]
err_up = fs8_upper .- data
err_low = data .- fs8_lower
err = (fs8_upper .- fs8_lower) ./ 2

cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    
    return (data_name = "data_fs8", z = z, data = data, err = err, cov = cov)
end

# # aiso data
# function fakedata_aiso()
#     z  = sort(2.5 .* rand(12)) 
#     dvz_cb = ((z .* LimberJack.CLIGHT_HMPC) .* ((cosmo1.chi(z)) .^ 2)) ./ (cosmo1.cpar.h .* 100 .* Ez(cosmo1, z))
#     data = (dvz_cb .^ (1/3)) ./ rd_fid
#     err = 0.1 .* data
#     cov = zeros(length(z), length(z))
#     for i in 1:length(z)
#         cov[i, i] = err[i]^2
#     end
#     return(data_name = "fakedata_aiso", z = z, data = data, cov = cov)
# end

# # aap data
# function fakedata_aap()
#     z = sort([[0.01, 0.02, 0.03, 0.05, 0.06, 0.07] ; (2.5 .* rand(4))])
#     data = LimberJack.CLIGHT_HMPC ./ (cosmo1.cpar.h .* 100 .* Ez(cosmo1, z) .* (cosmo1.chi(z)))
#     err = 0.1 .* data
#     cov = zeros(length(z), length(z))
#     for i in 1:length(z)
#         cov[i, i] = err[i]^2
#     end
#     return(data_name = "fakedata_aap", z = z, data = data, cov = cov)
# end


# supernovae data
function fakedata_mu()
    z = sort([[0.01, 0.02, 0.05, 0.09] ; (2.5 .* rand(4))])
    zhel = z .+ 0.0002
    d_lum = (1 .+ zhel) .* (cosmo1.chi(z))
    mu_initz = 5 .* log10.( abs.(d_lum) ./ 10 ) .+ 25
    M_samp = -19.3 + 5*log10(LimberJack.CLIGHT_HMPC/(cosmo1.cpar.h*100))
    data = mu_initz .+ 19.3 .+ M_samp 
    # data = 5 .* log10.(d_lum) .+ 25 .+ 0.5
    err = 0.1 .* data
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    return(data_name = "fakedata_mu", z = z, zhel = zhel, data = data, cov = cov)
end
# Out:
# fakedata_mu (generic function with 1 method)

# %%
datafs8 = data_fs8();

# %%
# correlation matrix
function cov_to_cor(covariance)
    std_devs = sqrt.(diag(covariance))
    return covariance ./ (std_devs * std_devs')
end
# Out:
# cov_to_cor (generic function with 1 method)

# %%
function data_DESI()
    # DESI data
    z1 = [0.3, 0.51, 0.71, 0.92, 1.32, 1.49]
    z = repeat(z1, inner = 3)
    data_dvrd = [7.788174, 12.514437, 15.675560, 19.676985, 23.861806, 25.708520]
    data_dhdm = [3.053800, 1.637266, 1.165867, 0.844996, 0.470709, 0.426508]
    data_fs8 = [0.37784, 0.515897, 0.48384, 0.422208, 0.37468, 0.435]
    #data_fss8 = [0.377174, 0.513635, 0.483623, 0.422164, 0.376715, 0.434858]
    
    data = 
    [7.788174, 3.053800, 0.37784,   # BGS (z=0.30)
    12.514437, 1.637266, 0.515897, # LRG1 (z=0.51)
    15.675560, 1.165867, 0.48384,  # LRG2 (z=0.71)
    19.676985, 0.844996, 0.422208, # LRG3 (z=0.92)
    23.861806, 0.470709, 0.37468,  # ELG2 (z=1.32)
    25.708520, 0.426508, 0.435  ]   # QSO (z=1.49)

    # Full 18x18 Covariance Matrix for DESI 2024 Year 1 
    # Variables: [DV/rd, DH/DM, fσs8] per redshift bin
    # Source: arXiv:2411.12021 Appendix A
    C_total = zeros(18, 18);

    # BGS z=0.30
    C_total[1:3, 1:3] = 1e-4 * [
        1314.664401 -142.669742  109.427163;
        -142.669742  829.170940 -158.101737;
        109.427163 -158.101737   88.510877
    ]

    # LRG1 z=0.51
    C_total[4:6, 4:6] = 1e-4 * [
        541.309833   48.425593   -4.652853;
        48.425593   97.249820  -34.923265;
        -4.652853  -34.923265   41.295470
    ]

    # LRG2 z=0.71
    C_total[7:9, 7:9] = 1e-4 * [
        762.457717   39.781004   -1.896006;
        39.781004   36.344098  -17.341350;
        -1.896006  -17.341350   28.119682
    ]

    # LRG3 z=0.92
    C_total[10:12, 10:12] = 1e-4 * [
        847.499793   26.038900    3.257324;
        26.038900   16.251088  -10.044074;
        3.257324  -10.044074   22.370314
    ]

    # ELG2 z=1.32
    C_total[13:15, 13:15] = 1e-4 * [
    2342.506886   26.159601   13.521001;
        26.159601   10.309303   -6.654663;
        13.521001   -6.654663   13.997473
    ]

    # QSO z=1.49
    C_total[16:18, 16:18] = 1e-4 * [
    3013.788566   -2.205101   36.332110;
        -2.205101    5.845806   -6.747133;
        36.332110   -6.747133   19.785658
    ]

    full_covariance = cov_to_cor(C_total);
#pretty_table(full_covariance)

    cov_final = C_total
    for k in 1:6
        cov_final[3*k,3*k] = datafs8.cov[k,k]
    end

    for h in 1:6
        cov_final[(3*h)-2,3*h] = sqrt(cov_final[3*h,3*h] * C_total[(3*h)-2,(3*h)-2]) * full_covariance[(3*h)-2,3*h]
        cov_final[(3*h)-1,3*h] = sqrt(cov_final[3*h,3*h] * C_total[(3*h)-1,(3*h)-1]) * full_covariance[(3*h)-1,3*h]
        cov_final[3*h,(3*h)-2] = sqrt(cov_final[3*h,3*h] * C_total[(3*h)-2,(3*h)-2]) * full_covariance[(3*h)-2,3*h]
        cov_final[3*h,(3*h)-1] = sqrt(cov_final[3*h,3*h] * C_total[(3*h)-1,(3*h)-1]) * full_covariance[(3*h)-1,3*h]
    end

    cov = cov_final
    
    err_arr = sqrt.(diag(cov))
    err_dvrd = err_arr[1:3:end]
    err_dhdm = err_arr[2:3:end]
    err_fs8 = err_arr[3:3:end]

    return(data_name = "data_DESI", z = z, data = data, data_dvrd = data_dvrd, data_dhdm = data_dhdm, data_fs8 = data_fs8, err_dvrd = err_dvrd, err_dhdm = err_dhdm, err_fs8 = err_fs8, cov = cov)
end
# Out:
# data_DESI (generic function with 1 method)

# %%
dataDESI = data_DESI();
#fakedatahz = fakedata_hz();
#fakedatadm = fakedata_dm();
#fakedatafs8 = fakedata_fs8();
# fakedataaap = fakedata_aap();
# fakedataaiso = fakedata_aiso();
fakedatamu = fakedata_mu();
datahz = data_hz();

# %% [markdown]
# #### Putting data together

# %%
# data
# data_obs  = [datahz.data; fakedataaiso.data; fakedataaap.data; datafs8.data];
# z_obs = [datahz.z; fakedataaiso.z; fakedataaap.z; datafs8.z];
# covariance_obs = BlockDiagonal([datahz.cov, fakedataaiso.cov, fakedataaap.cov, datafs8.cov]);

data_obs = [datahz.data; dataDESI.data];
z_obs = [datahz.z; dataDESI.z];
covariance_obs = BlockDiagonal([datahz.cov, dataDESI.cov]);

# errors
hz_err = datahz.err;
aiso_err = dataDESI.err_dvrd;
aap_err = dataDESI.err_dhdm;
#fs8_err = datafs8.err;
fs8_err = dataDESI.err_fs8;
mu_err = 0.1 .* fakedatamu.data;

# %% [markdown]
# ### Functions for hz, dv/rd, dh/dm, fs8, mu

# %%
# outputs are arrays, not interpolators
function hz_from_ez(zarr, h0, ez)
    ez_itp = LinearInterpolation(zarr, ez, extrapolation_bc=Line())
    hz = ez_itp(zarr) .* (h0*100)
    #hzi = linear_interpolation(zarr, hz, extrapolation_bc=Line())
    return hz
end

function dm_from_ez(zarr, h0, ez)
    chis = similar(ez)
    ez_itp = LinearInterpolation(zarr, ez, extrapolation_bc=Line())

    for i in 1:length(zarr)
        zz = zarr[i]
        chis[i] = quadgk(z -> 1.0/ez_itp(z), 0.0, zz, rtol=1E-5)[1]
        chis[i] *= LimberJack.CLIGHT_HMPC / h0
    end
    return chis
end


function fs8_from_ez(zarr, Ωm, σ8, h0, ez, cosmo_type)
    # initialising
    nz = length(zarr)
    z_max = maximum(zarr)
    x = log.(1 .+ zarr)
    a = @.(1/(1+zarr))
    dx = x[2]-x[1]
    
    aa = reverse(a)
    ee = reverse(ez)
    dd = zeros(cosmo_type, nz)
    yy = zeros(cosmo_type, nz)
    dd[1] = aa[1]
    yy[1] = aa[1]^3*ee[end]
    
    for i in 1:(nz-1)
        A0 = -1.5 * Ωm / (aa[i]*ee[i])
        B0 = -1. / (aa[i]^2*ee[i])
        A1 = -1.5 * Ωm / (aa[i+1]*ee[i+1])
        B1 = -1. / (aa[i+1]^2*ee[i+1])
        yy[i+1] = (1+0.5*dx^2*A0*B0)*yy[i] + 0.5*(A0+A1)*dx*dd[i]
        dd[i+1] = 0.5*(B0+B1)*dx*yy[i] + (1+0.5*dx^2*A0*B0)*dd[i]
    end
    
    y = reverse(yy)
    d = reverse(dd)

    fs8zi =  -σ8 .* y./ (a.^2 .*ez.*d[1])
                                
                        
    return fs8zi
end


function dh(zarr, h0, ez)
    dhz = LimberJack.CLIGHT_HMPC ./ (hz_from_ez(zarr, h0, ez))
    return dhz
end

function dv(zarr, h0, ez)
    chis = similar(ez)
    ez_itp = LinearInterpolation(zarr, ez, extrapolation_bc=Line())

    for i in 1:length(zarr)
        zz = zarr[i]
        chis[i] = quadgk(z -> 1.0/ez_itp(z), 0.0, zz, rtol=1E-5)[1]
        chis[i] *= LimberJack.CLIGHT_HMPC / h0
    end
    
    dvs = similar(chis)
    for i in 1:length(zarr)
        zz = zarr[i]
        dvz_cbrt = zz * (LimberJack.CLIGHT_HMPC/(ez_itp(zz)*h0*100)) * (chis[i]^2)
        dvs[i] = dvz_cbrt^(1/3)
    end

    return dvs
end

function a_ap(zarr, h0, ez)
  numer = dh(zarr, h0, ez) ./ dm_from_ez(zarr, h0, ez)
  return numer 
end

function a_iso(zarr, h0, rd, ez)
    numer = dv(zarr, h0, ez) ./ rd
    return numer 
end

# function d_lum(zarr, h0, ez)
#     dlz = (1 .+ zarr) .* dm_from_ez(zarr, h0, ez)
#     return dlz
# end

# function mu1(zarr, h0, M, ez)
#     muz = 5 .* log10.( abs.(d_lum(zarr, h0, ez)) ) .+ 25 .+ M
#     return muz
# end


function d_lum(z_hel, zarr, h0, ez)
    dlz = (1 .+ z_hel) .* dm_from_ez(zarr, h0, ez)
    return dlz
end

function mu_init(z_hel, zarr, h0, ez)
    mu_initz = 5 .* log10.( abs.(d_lum(z_hel, zarr, h0, ez)) ./ 10 ) .+ 25 
    return mu_initz
end

function mu(z_hel, zarr, h0, M, ez)
    M_samp = M + 5*log10(LimberJack.CLIGHT_HMPC/(h0*100))
    muz = mu_init(z_hel, zarr, h0, ez) .+ 19.3 .+ M_samp
    return muz
end
# Out:
# mu (generic function with 1 method)

# %%
# supernovae data
supernovae = CSV.read("DES_Dovekie_HD.csv", DataFrame);
function data_mu()
    z = supernovae[!,"zHD"][1:100]
    z_hel = supernovae[!,"zHEL"][1:100]
    data = supernovae[!,"MU"][1:100]
    err = supernovae[!,"MUERR"][1:100]
    
    cov = zeros(length(z), length(z))
    for i in 1:length(z)
        cov[i, i] = err[i]^2
    end
    
    return (data_name = "data_mu", z = z, data = data, err = err, cov = cov)
end
# Out:
# 10-element Vector{Float64}:
#  0.02509
#  0.0251
#  0.0251
#  0.02512
#  0.02517
#  0.02519
#  0.02534
#  0.02534
#  0.02556
#  0.02557

# %%
z_integ1 = cosmo1.settings.zs;
ez_test = Ez(cosmo1, z_integ1);
z_hel1 = z_integ1 .+ 0.0002;

# %%
p0 = plot(datahz.z, datahz.data, yerr=hz_err, seriestype=:scatter,title="H(z)", legend=false)
p1 = plot(datafs8.z, dataDESI.data_dvrd, yerr=aiso_err, seriestype=:scatter,title="aiso(z)", legend=false)
p2 = plot(datafs8.z, dataDESI.data_dhdm, yerr=aap_err, seriestype=:scatter, title="aap(z)", legend=false)
p3 = plot(datafs8.z, dataDESI.data_fs8, yerr=fs8_err, seriestype=:scatter, title="fs8(z)", legend=false)
p4 = plot(fakedatamu.z, fakedatamu.data, yerr=mu_err, seriestype=:scatter, title="mu(z)", legend=false)

plot!(p0, z_integ1, hz_from_ez(z_integ1, cosmo1.cpar.h, ez_test), color=:black)
plot!(p1, z_integ1, a_iso(z_integ1, cosmo1.cpar.h, rd_fid, ez_test), color=:black)
plot!(p2, z_integ1, a_ap(z_integ1, cosmo1.cpar.h, ez_test), color=:black)
plot!(p3, z_integ1, fs8_from_ez(z_integ1, cosmo1.cpar.Ωm, cosmo1.cpar.σ8, cosmo1.cpar.h, ez_test, eltype(ez_test)), color=:black)
plot!(p4, z_integ1, mu(z_hel1, z_integ1, cosmo1.cpar.h, -19.3, ez_test), color=:black)

plot(p0, p1, p2, p3, p4, layout=(2,3), size=(900,600))

# %% [markdown]
# ## LCDM analysis

# %%
@model function LCDM_model(data, data_cov)
    # Priors
    omegam_pr ~ omegam_dist
    h0_pr ~ h0_dist
    s8_pr ~ s8_dist
    rd_pr ~ rd_dist
    #M_pr ~ M_dist

    # Create cosmology
    cosmo_pr = LimberJack.Cosmology(Ωm=cosmo1.cpar.Ωm, Ωb=cosmo1.cpar.Ωb, h=cosmo1.cpar.h, σ8=s8_pr);
    
    # Model predictions
    ez_model = Ez(cosmo_pr, z_integ1)
    hz_model := hz_from_ez(z_integ1, h0_pr, ez_model)
    dv_rd_model := a_iso(z_integ1, h0_pr, rd_pr, ez_model) 
    dh_dm_model := a_ap(z_integ1, h0_pr, ez_model)
    fs8_model := fs8_from_ez(z_integ1, omegam_pr, s8_pr, h0_pr, ez_model, eltype(ez_model))
    #mu_model = mu(z_integ1, h0_pr, M_pr, ez_model)

    # Create interpolators
    hz_itp = LinearInterpolation(z_integ1, hz_model, extrapolation_bc=Line())
    dvrd_itp = LinearInterpolation(z_integ1, dv_rd_model, extrapolation_bc=Line())
    dhdm_itp = LinearInterpolation(z_integ1, dh_dm_model, extrapolation_bc=Line())
    fs8_itp = LinearInterpolation(z_integ1, fs8_model, extrapolation_bc=Line())
    #mu_itp = LinearInterpolation(z_integ1, mu_model, extrapolation_bc=Line())

    hz_theory := hz_itp(datahz.z)
    dvrd_theory := dvrd_itp(datafs8.z)
    dhdm_theory := dhdm_itp(datafs8.z)
    fs8_theory := fs8_itp(datafs8.z)
    #mu_theory := mu_itp(fakedatamu.z)

    theory = [hz_theory; dvrd_theory; dhdm_theory; fs8_theory]

    # Likelihood
    data ~ MvNormal(theory, data_cov)
end
# Out:
# LCDM_model (generic function with 2 methods)

# %%
cond_LCDM_model = LCDM_model(data_obs, covariance_obs)
chain_LCDM = sample(cond_LCDM_model, NUTS(20, 0.7), 100)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# ┌ Info: Found initial step size
# │   ϵ = 0.05
# └ @ Turing.Inference /Users/vis/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:212
# Sampling   1%|▍                                         |  ETA: 1:04:49
# Sampling   2%|▊                                         |  ETA: 0:32:18
# Sampling   2%|█                                         |  ETA: 0:21:23
# Sampling   3%|█▍                                        |  ETA: 0:15:57
# Sampling   4%|█▊                                        |  ETA: 0:12:41
# Sampling   5%|██▏                                       |  ETA: 0:10:31
# Sampling   6%|██▌                                       |  ETA: 0:08:58
# Sampling   7%|██▊                                       |  ETA: 0:07:49
# Sampling   8%|███▏                                      |  ETA: 0:07:04
# Sampling   8%|███▌                                      |  ETA: 0:06:20
# Sampling   9%|███▉                                      |  ETA: 0:05:44
# Sampling  10%|████▎                                     |  ETA: 0:05:13
# Sampling  11%|████▌                                     |  ETA: 0:04:50
# Sampling  12%|████▉                                     |  ETA: 0:04:28
# Sampling  12%|█████▎                                    |  ETA: 0:04:09
# Sampling  13%|█████▋                                    |  ETA: 0:03:54
# Sampling  14%|██████                                    |  ETA: 0:03:39
# Sampling  15%|██████▎                                   |  ETA: 0:03:26
# Sampling  16%|██████▋                                   |  ETA: 0:03:15
# Sampling  17%|███████                                   |  ETA: 0:03:04
# Sampling  18%|███████▍                                  |  ETA: 0:02:54
# Sampling  18%|███████▊                                  |  ETA: 0:02:46
# Sampling  19%|████████                                  |  ETA: 0:02:38
# Sampling  20%|████████▍                                 |  ETA: 0:02:31
# Sampling  21%|████████▊                                 |  ETA: 0:02:24
# Sampling  22%|█████████▏                                |  ETA: 0:02:18
# Sampling  22%|█████████▌                                |  ETA: 0:02:12
# Sampling  23%|█████████▊                                |  ETA: 0:02:06
# Sampling  24%|██████████▏                               |  ETA: 0:02:01
# Sampling  25%|██████████▌                               |  ETA: 0:01:56
# Sampling  26%|██████████▉                               |  ETA: 0:01:52
# Sampling  27%|███████████▎                              |  ETA: 0:01:47
# Sampling  28%|███████████▌                              |  ETA: 0:01:43
# Sampling  28%|███████████▉                              |  ETA: 0:01:40
# Sampling  29%|████████████▎                             |  ETA: 0:01:36
# Sampling  30%|████████████▋                             |  ETA: 0:01:32
# Sampling  31%|█████████████                             |  ETA: 0:01:29
# Sampling  32%|█████████████▎                            |  ETA: 0:01:26
# Sampling  32%|█████████████▋                            |  ETA: 0:01:23
# Sampling  33%|██████████████                            |  ETA: 0:01:20
# Sampling  34%|██████████████▍                           |  ETA: 0:01:17
# Sampling  35%|██████████████▊                           |  ETA: 0:01:15
# Sampling  36%|███████████████                           |  ETA: 0:01:12
# Sampling  37%|███████████████▍                          |  ETA: 0:01:10
# Sampling  38%|███████████████▊                          |  ETA: 0:01:08
# Sampling  38%|████████████████▏                         |  ETA: 0:01:06
# Sampling  39%|████████████████▌                         |  ETA: 0:01:04
# Sampling  40%|████████████████▊                         |  ETA: 0:01:02
# Sampling  41%|█████████████████▏                        |  ETA: 0:01:00
# Sampling  42%|█████████████████▌                        |  ETA: 0:00:58
# Sampling  42%|█████████████████▉                        |  ETA: 0:00:56
# Sampling  43%|██████████████████▎                       |  ETA: 0:00:55
# Sampling  44%|██████████████████▌                       |  ETA: 0:00:53
# Sampling  45%|██████████████████▉                       |  ETA: 0:00:51
# Sampling  46%|███████████████████▎                      |  ETA: 0:00:50
# Sampling  47%|███████████████████▋                      |  ETA: 0:00:48
# Sampling  48%|████████████████████                      |  ETA: 0:00:47
# Sampling  48%|████████████████████▎                     |  ETA: 0:00:46
# Sampling  49%|████████████████████▋                     |  ETA: 0:00:44
# Sampling  50%|█████████████████████                     |  ETA: 0:00:43
# Sampling  51%|█████████████████████▍                    |  ETA: 0:00:42
# Sampling  52%|█████████████████████▊                    |  ETA: 0:00:41
# Sampling  52%|██████████████████████                    |  ETA: 0:00:39
# Sampling  53%|██████████████████████▍                   |  ETA: 0:00:38
# Sampling  54%|██████████████████████▊                   |  ETA: 0:00:37
# Sampling  55%|███████████████████████▏                  |  ETA: 0:00:36
# Sampling  56%|███████████████████████▌                  |  ETA: 0:00:35
# Sampling  57%|███████████████████████▊                  |  ETA: 0:00:34
# Sampling  57%|████████████████████████▏                 |  ETA: 0:00:33
# Sampling  58%|████████████████████████▌                 |  ETA: 0:00:32
# Sampling  59%|████████████████████████▉                 |  ETA: 0:00:31
# Sampling  60%|█████████████████████████▎                |  ETA: 0:00:30
# Sampling  61%|█████████████████████████▌                |  ETA: 0:00:29
# Sampling  62%|█████████████████████████▉                |  ETA: 0:00:29
# Sampling  62%|██████████████████████████▎               |  ETA: 0:00:28
# Sampling  63%|██████████████████████████▋               |  ETA: 0:00:27
# Sampling  64%|███████████████████████████               |  ETA: 0:00:26
# Sampling  65%|███████████████████████████▎              |  ETA: 0:00:25
# Sampling  66%|███████████████████████████▋              |  ETA: 0:00:25
# Sampling  67%|████████████████████████████              |  ETA: 0:00:24
# Sampling  68%|████████████████████████████▍             |  ETA: 0:00:23
# Sampling  68%|████████████████████████████▊             |  ETA: 0:00:22
# Sampling  69%|█████████████████████████████             |  ETA: 0:00:21
# Sampling  70%|█████████████████████████████▍            |  ETA: 0:00:21
# Sampling  71%|█████████████████████████████▊            |  ETA: 0:00:20
# Sampling  72%|██████████████████████████████▏           |  ETA: 0:00:19
# Sampling  72%|██████████████████████████████▌           |  ETA: 0:00:18
# Sampling  73%|██████████████████████████████▊           |  ETA: 0:00:18
# Sampling  74%|███████████████████████████████▏          |  ETA: 0:00:17
# Sampling  75%|███████████████████████████████▌          |  ETA: 0:00:17
# Sampling  76%|███████████████████████████████▉          |  ETA: 0:00:16
# Sampling  77%|████████████████████████████████▎         |  ETA: 0:00:15
# Sampling  78%|████████████████████████████████▌         |  ETA: 0:00:15
# Sampling  78%|████████████████████████████████▉         |  ETA: 0:00:14
# Sampling  79%|█████████████████████████████████▎        |  ETA: 0:00:13
# Sampling  80%|█████████████████████████████████▋        |  ETA: 0:00:13
# Sampling  81%|██████████████████████████████████        |  ETA: 0:00:12
# Sampling  82%|██████████████████████████████████▎       |  ETA: 0:00:12
# Sampling  82%|██████████████████████████████████▋       |  ETA: 0:00:11
# Sampling  83%|███████████████████████████████████       |  ETA: 0:00:10
# Sampling  84%|███████████████████████████████████▍      |  ETA: 0:00:10
# Sampling  85%|███████████████████████████████████▊      |  ETA: 0:00:09
# Sampling  86%|████████████████████████████████████      |  ETA: 0:00:09
# Sampling  87%|████████████████████████████████████▍     |  ETA: 0:00:08
# Sampling  88%|████████████████████████████████████▊     |  ETA: 0:00:08
# Sampling  88%|█████████████████████████████████████▏    |  ETA: 0:00:07
# Sampling  89%|█████████████████████████████████████▌    |  ETA: 0:00:07
# Sampling  90%|█████████████████████████████████████▊    |  ETA: 0:00:06
# Sampling  91%|██████████████████████████████████████▏   |  ETA: 0:00:05
# Sampling  92%|██████████████████████████████████████▌   |  ETA: 0:00:05
# Sampling  92%|██████████████████████████████████████▉   |  ETA: 0:00:04
# Sampling  93%|███████████████████████████████████████▎  |  ETA: 0:00:04
# Sampling  94%|███████████████████████████████████████▌  |  ETA: 0:00:03
# Sampling  95%|███████████████████████████████████████▉  |  ETA: 0:00:03
# Sampling  96%|████████████████████████████████████████▎ |  ETA: 0:00:02
# Sampling  97%|████████████████████████████████████████▋ |  ETA: 0:00:02
# Sampling  98%|█████████████████████████████████████████ |  ETA: 0:00:01
# Sampling  98%|█████████████████████████████████████████▎|  ETA: 0:00:01
# Sampling  99%|█████████████████████████████████████████▋|  ETA: 0:00:00
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:56
# Sampling 100%|██████████████████████████████████████████| Time: 0:01:06
# Chains MCMC chain (100×1271×1 Array{Float64, 3}):
#
# Iterations        = 21:1:120
# Number of chains  = 1
# Samples per chain = 100
# Wall duration     = 59.41 seconds
# Compute duration  = 59.41 seconds
# parameters        = omegam_pr, h0_pr, s8_pr, rd_pr, hz_model[1], hz_model[2], hz_model[3], hz_model[4], hz_model[5], hz_model[6], hz_model[7], hz_model[8], hz_model[9], hz_model[10], hz_model[11], hz_model[12], hz_model[13], hz_model[14], hz_model[15], hz_model[16], hz_model[17], hz_model[18], hz_model[19], hz_model[20], hz_model[21], hz_model[22], hz_model[23], hz_model[24], hz_model[25], hz_model[26], hz_model[27], hz_model[28], hz_model[29], hz_model[30], hz_model[31], hz_model[32], hz_model[33], hz_model[34], hz_model[35], hz_model[36], hz_model[37], hz_model[38], hz_model[39], hz_model[40], hz_model[41], hz_model[42], hz_model[43], hz_model[44], hz_model[45], hz_model[46], hz_model[47], hz_model[48], hz_model[49], hz_model[50], hz_model[51], hz_model[52], hz_model[53], hz_model[54], hz_model[55], hz_model[56], hz_model[57], hz_model[58], hz_model[59], hz_model[60], hz_model[61], hz_model[62], hz_model[63], hz_model[64], hz_model[65], hz_model[66], hz_model[67], hz_model[68], hz_model[69], hz_model[70], hz_model[71], hz_model[72], hz_model[73], hz_model[74], hz_model[75], hz_model[76], hz_model[77], hz_model[78], hz_model[79], hz_model[80], hz_model[81], hz_model[82], hz_model[83], hz_model[84], hz_model[85], hz_model[86], hz_model[87], hz_model[88], hz_model[89], hz_model[90], hz_model[91], hz_model[92], hz_model[93], hz_model[94], hz_model[95], hz_model[96], hz_model[97], hz_model[98], hz_model[99], hz_model[100], hz_model[101], hz_model[102], hz_model[103], hz_model[104], hz_model[105], hz_model[106], hz_model[107], hz_model[108], hz_model[109], hz_model[110], hz_model[111], hz_model[112], hz_model[113], hz_model[114], hz_model[115], hz_model[116], hz_model[117], hz_model[118], hz_model[119], hz_model[120], hz_model[121], hz_model[122], hz_model[123], hz_model[124], hz_model[125], hz_model[126], hz_model[127], hz_model[128], hz_model[129], hz_model[130], hz_model[131], hz_model[132], hz_model[133], hz_model[134], hz_model[135], hz_model[136], hz_model[137], hz_model[138], hz_model[139], hz_model[140], hz_model[141], hz_model[142], hz_model[143], hz_model[144], hz_model[145], hz_model[146], hz_model[147], hz_model[148], hz_model[149], hz_model[150], hz_model[151], hz_model[152], hz_model[153], hz_model[154], hz_model[155], hz_model[156], hz_model[157], hz_model[158], hz_model[159], hz_model[160], hz_model[161], hz_model[162], hz_model[163], hz_model[164], hz_model[165], hz_model[166], hz_model[167], hz_model[168], hz_model[169], hz_model[170], hz_model[171], hz_model[172], hz_model[173], hz_model[174], hz_model[175], hz_model[176], hz_model[177], hz_model[178], hz_model[179], hz_model[180], hz_model[181], hz_model[182], hz_model[183], hz_model[184], hz_model[185], hz_model[186], hz_model[187], hz_model[188], hz_model[189], hz_model[190], hz_model[191], hz_model[192], hz_model[193], hz_model[194], hz_model[195], hz_model[196], hz_model[197], hz_model[198], hz_model[199], hz_model[200], hz_model[201], hz_model[202], hz_model[203], hz_model[204], hz_model[205], hz_model[206], hz_model[207], hz_model[208], hz_model[209], hz_model[210], hz_model[211], hz_model[212], hz_model[213], hz_model[214], hz_model[215], hz_model[216], hz_model[217], hz_model[218], hz_model[219], hz_model[220], hz_model[221], hz_model[222], hz_model[223], hz_model[224], hz_model[225], hz_model[226], hz_model[227], hz_model[228], hz_model[229], hz_model[230], hz_model[231], hz_model[232], hz_model[233], hz_model[234], hz_model[235], hz_model[236], hz_model[237], hz_model[238], hz_model[239], hz_model[240], hz_model[241], hz_model[242], hz_model[243], hz_model[244], hz_model[245], hz_model[246], hz_model[247], hz_model[248], hz_model[249], hz_model[250], hz_model[251], hz_model[252], hz_model[253], hz_model[254], hz_model[255], hz_model[256], hz_model[257], hz_model[258], hz_model[259], hz_model[260], hz_model[261], hz_model[262], hz_model[263], hz_model[264], hz_model[265], hz_model[266], hz_model[267], hz_model[268], hz_model[269], hz_model[270], hz_mod ...
# internals         = lp, n_steps, is_accept, acceptance_rate, log_density, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size
#
# Summary Statistics
#     parameters       mean       std      mcse   ess_bulk   ess_tail      rhat  ⋯
#         Symbol    Float64   Float64   Float64    Float64    Float64   Float64  ⋯
#
#      omegam_pr     0.3290    0.0165    0.0022    48.2552    54.8565    1.0074  ⋯
#          h0_pr     0.8000    0.0000    0.0000    44.8622    47.5079    0.9953  ⋯
#          s8_pr     0.7749    0.0395    0.0044    87.8623    71.2875    1.0014  ⋯
#          rd_pr   109.9966    0.0026    0.0003    78.2408    48.4362    1.0523  ⋯
#    hz_model[1]    79.9973    0.0026    0.0003    44.8622    47.5079    0.9954  ⋯
#    hz_model[2]    80.1653    0.0026    0.0003    44.8622    47.5079    0.9953  ⋯
#    hz_model[3]    80.3353    0.0026    0.0003    44.8622    47.5079    0.9954  ⋯
#    hz_model[4]    80.5072    0.0026    0.0003    44.8622    47.5079    0.9953  ⋯
#    hz_model[5]    80.6812    0.0026    0.0003    44.8622    47.5079    0.9953  ⋯
#    hz_model[6]    80.8573    0.0026    0.0003    44.8622    47.5079    0.9953  ⋯
#    hz_model[7]    81.0354    0.0026    0.0003    44.8622    47.5079    0.9954  ⋯
#    hz_model[8]    81.2157    0.0026    0.0003    44.8622    47.5079    0.9954  ⋯
#    hz_model[9]    81.3980    0.0026    0.0003    44.8622    47.5079    0.9954  ⋯
#   hz_model[10]    81.5825    0.0027    0.0003    44.8622    47.5079    0.9954  ⋯
#   hz_model[11]    81.7692    0.0027    0.0003    44.8622    47.5079    0.9954  ⋯
#   hz_model[12]    81.9580    0.0027    0.0003    44.8622    47.5079    0.9953  ⋯
#   hz_model[13]    82.1490    0.0027    0.0003    44.8622    47.5079    0.9953  ⋯
#        ⋮            ⋮          ⋮         ⋮         ⋮          ⋮          ⋮     ⋱
#                                                   1 column and 1242 rows omitted
#
# Quantiles
#     parameters       2.5%      25.0%      50.0%      75.0%      97.5%
#         Symbol    Float64    Float64    Float64    Float64    Float64
#
#      omegam_pr     0.2831     0.3204     0.3324     0.3412     0.3494
#          h0_pr     0.7999     0.8000     0.8000     0.8000     0.8000
#          s8_pr     0.7025     0.7501     0.7736     0.7975     0.8584
#          rd_pr   109.9898   109.9956   109.9970   109.9985   109.9994
#    hz_model[1]    79.9895    79.9962    79.9982    79.9992    79.9999
#    hz_model[2]    80.1574    80.1642    80.1662    80.1672    80.1678
#    hz_model[3]    80.3274    80.3342    80.3361    80.3372    80.3378
#    hz_model[4]    80.4993    80.5061    80.5081    80.5092    80.5098
#    hz_model[5]    80.6733    80.6801    80.6821    80.6832    80.6838
#    hz_model[6]    80.8494    80.8562    80.8582    80.8592    80.8599
#    hz_model[7]    81.0275    81.0343    81.0363    81.0374    81.0380
#    hz_model[8]    81.2077    81.2146    81.2166    81.2176    81.2183
#    hz_model[9]    81.3901    81.3969    81.3989    81.4000    81.4006
#   hz_model[10]    81.5745    81.5814    81.5834    81.5845    81.5851
#   hz_model[11]    81.7612    81.7681    81.7701    81.7711    81.7718
#   hz_model[12]    81.9500    81.9569    81.9589    81.9600    81.9606
#   hz_model[13]    82.1410    82.1479    82.1499    82.1510    82.1517
#        ⋮            ⋮          ⋮          ⋮          ⋮          ⋮
#                                                       1242 rows omitted

# %%
# lcdm chains
hzdata_lcdm = group(chain_LCDM, :hz_model).value.data[:,:,1];
aisodata_lcdm = group(chain_LCDM, :dv_rd_model).value.data[:,:,1];
aapdata_lcdm = group(chain_LCDM, :dh_dm_model).value.data[:,:,1];
fs8data_lcdm = group(chain_LCDM, :fs8_model).value.data[:,:,1];
#mudata_lcdm = group(chain_LCDM, :mu_model).value.data[:,:,1];

# mean and standard deviation - lcdm
hz_lcdm_m, hz_lcdm_s = mean(hzdata_lcdm, dims=1), std(hzdata_lcdm, dims=1); 
aiso_lcdm_m, aiso_lcdm_s = mean(aisodata_lcdm, dims=1), std(aisodata_lcdm, dims=1);
aap_lcdm_m, aap_lcdm_s = mean(aapdata_lcdm, dims=1), std(aapdata_lcdm, dims=1); 
fs8_lcdm_m, fs8_lcdm_s = mean(fs8data_lcdm, dims=1), std(fs8data_lcdm, dims=1); 
#mu_lcdm_m, mu_lcdm_s = mean(mudata_lcdm, dims=1), std(mudata_lcdm, dims=1);
# Out:
# ([0.3742719175925307 0.375184081603609 … -0.09365617083610787 -0.09707196573667734], [0.015583005426190212 0.015616390312590923 … 0.007396801946544152 0.007514011147211021])

# %%
plot(datahz.z, datahz.data, yerr=hz_err, label="Data H(z)", ms=2, seriestype=:scatter)
plot!(z_integ1, vec(hz_lcdm_m), label=" H(z) LCDM mean")
plot!(z_integ1, vec(hz_lcdm_m .- hz_lcdm_s),  fillrange = vec(hz_lcdm_m .+ hz_lcdm_s), fillalpha=0.2, c=1, label="H(z) LCDM standard deviation")

# %%
plot(datafs8.z, dataDESI.data_dvrd, yerr=aiso_err, label="Data a_iso", ms=2, seriestype=:scatter)
plot!(z_integ1, vec(aiso_lcdm_m), label=" a_iso LCDM mean")
plot!(z_integ1, vec(aiso_lcdm_m .- aiso_lcdm_s),  fillrange = vec(aiso_lcdm_m .+ aiso_lcdm_s), fillalpha=0.2, c=1, label="a_iso LCDM standard deviation")

# %%
plot(datafs8.z, dataDESI.data_dhdm, yerr=aap_err, label="Data a_ap", ms=2, seriestype=:scatter)
plot!(z_integ1, vec(aap_lcdm_m), label="a_ap LCDM mean")
plot!(z_integ1, vec(aap_lcdm_m .- aap_lcdm_s),  fillrange = vec(aap_lcdm_m .+ aap_lcdm_s), fillalpha=0.2, c=1, label="a_ap LCDM standard deviation")

# %%
plot(datafs8.z, datafs8.data, yerr=fs8_err, label="Data fs8", ms=2, seriestype=:scatter)
plot!(z_integ1, vec(fs8_lcdm_m), label="fs8 lcdm")
plot!(z_integ1, vec(fs8_lcdm_m .- fs8_lcdm_s),  fillrange = vec(fs8_lcdm_m .+ fs8_lcdm_s), fillalpha=0.2, c=1, label="fs8 lcdm standard deviation")

# %%
# plot(fakedatamu.z, fakedatamu.data, yerr=mu_err, label="Data mu", ms=2, seriestype=:scatter)
# plot!(z_integ1, vec(mu_lcdm_m), label="mu lcdm")
# plot!(z_integ1, vec(mu_lcdm_m .- mu_lcdm_s),  fillrange = vec(mu_lcdm_m .+ mu_lcdm_s), fillalpha=0.2, c=1, label="mu lcdm standard deviation")

# %%
zlat = range(0, 3.0, length=15); # latent variable space
z_integ = cosmo1.settings.zs; # integral variable space

# %%
function model_latent_GP(eta, l, v; omega_m=cosmo1.cpar.Ωm, sigma_8=cosmo1.cpar.σ8, h_0 = cosmo1.cpar.h,
                         x=zlat, z=z_obs, data_cov=covariance_obs)
    # Dimensions of predictors .
    kernel = sqexp_cov_fn(x; eta=eta, l=l)
    cpar = CosmoPar(Ωm=omega_m,  Ωb=cosmo1.cpar.Ωb, h=h_0, σ8=sigma_8)
    mean_ex = Ez(cpar, x)
    # a latent GP is carried out using a Wiener filter
    ex = latent_GP(mean_ex, v, kernel)
    # transforms hx from x space to z space
    ez =  conditional(x, z, ex, sqexp_cov_fn;
                     eta=eta, l=l)
    return ex, ez
end
# Out:
# model_latent_GP (generic function with 1 method)

# %%
@model function stats_model(y; int_grid=z_integ, X=zlat, data_x=z_obs, data_cov=covariance_obs)
    # Priors, parameters
    eta2 = 50
    l2 = 0.3
    v_po ~ MvNormal(zeros(length(X)), ones(length(X)))
    omegam_po ~ omegam_dist
    s8_po ~ s8_dist
    h_po ~ h0_dist
    r_po ~ rd_dist
    #M_po ~ M_dist
    
    kernel = sqexp_cov_fn(X, eta=eta2, l=l2)
    cpar = CosmoPar(Ωm=cosmo1.cpar.Ωm, Ωb=cosmo1.cpar.Ωb, h=cosmo1.cpar.h, σ8=s8_po)
    mean_ez = Ez(cpar, X)
    ez_latent = latent_GP(mean_ez, v_po, kernel)
    ez_gp = conditional(X, int_grid, ez_latent, sqexp_cov_fn; eta=eta2, l=l2) # converting from latent space to integral space
    
    # sampling over parameters
    hz = hz_from_ez(int_grid, h_po, ez_gp);
    aiso = a_iso(int_grid, h_po, r_po, ez_gp);
    aap = a_ap(int_grid, h_po, ez_gp);
    fs8 = fs8_from_ez(int_grid, omegam_po, s8_po, h_po, ez_gp, eltype(ez_gp));
    #mu_mod = mu(int_grid, h_po, M_po, ez_gp);

    hz_interp = LinearInterpolation(int_grid, hz, extrapolation_bc=Line())
    aiso_interp = LinearInterpolation(int_grid, aiso, extrapolation_bc=Line())
    aap_interp = LinearInterpolation(int_grid, aap, extrapolation_bc=Line())
    fs8_interp = LinearInterpolation(int_grid, fs8, extrapolation_bc=Line())
    #mu_interp = LinearInterpolation(int_grid, mu_mod, extrapolation_bc=Line())

    hdata := hz_interp(datahz.z)
    aisodata := aiso_interp(datafs8.z)
    aapdata := aap_interp(datafs8.z)
    fs8data := fs8_interp(datafs8.z)
    #mudata := mu_interp(fakedatamu.z)
   

    datay = [hdata;aisodata;aapdata;fs8data]

    y ~ MvNormal(datay, data_cov) 

end
# Out:
# stats_model (generic function with 2 methods)

# %%
#init_params = [h_po => 0.7, omegam_po => 0.3]
chain_gp = sample(stats_model(data_obs), NUTS(20, 0.7, init_ϵ=0.1), 100)
# Out:
# Sampling   0%|                                          |  ETA: N/A
# Sampling   1%|▍                                         |  ETA: 0:52:57
# Sampling   2%|▊                                         |  ETA: 0:26:30
# Sampling   2%|█                                         |  ETA: 0:17:37
# Sampling   3%|█▍                                        |  ETA: 0:13:11
# Sampling   4%|█▊                                        |  ETA: 0:10:32
# Sampling   5%|██▏                                       |  ETA: 0:08:45
# Sampling   6%|██▌                                       |  ETA: 0:07:29
# Sampling   7%|██▊                                       |  ETA: 0:06:32
# Sampling   8%|███▏                                      |  ETA: 0:05:47
# Sampling   8%|███▌                                      |  ETA: 0:05:12
# Sampling   9%|███▉                                      |  ETA: 0:04:43
# Sampling  10%|████▎                                     |  ETA: 0:04:19
# Sampling  11%|████▌                                     |  ETA: 0:03:59
# Sampling  12%|████▉                                     |  ETA: 0:03:43
# Sampling  12%|█████▎                                    |  ETA: 0:03:28
# Sampling  13%|█████▋                                    |  ETA: 0:03:15
# Sampling  14%|██████                                    |  ETA: 0:03:03
# Sampling  15%|██████▎                                   |  ETA: 0:02:53
# Sampling 100%|██████████████████████████████████████████| Time: 0:00:30
# DomainError with 0.46910099479571965:
#
# integrand produced Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}}(NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN) in the interval (0.4691009947957163, 0.46910099479572304)
#
#
#
# Stacktrace:
#
#   [1] evalrule(f::var"#17#18"{Interpolations.Extrapolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, 1, Interpolations.GriddedInterpolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, 1, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Gridded{Linear{Throw{OnGrid}}}, Tuple{Vector{Float64}}}, Gridded{Linear{Throw{OnGrid}}}, Line{Nothing}}}, a::Float64, b::Float64, x::Vector{Float64}, w::Vector{Float64}, wg::Vector{Float64}, nrm::typeof(norm))
#
#     @ QuadGK ~/.julia/packages/QuadGK/7rND3/src/evalrule.jl:39
#
#   [2] refine(f::var"#17#18"{Interpolations.Extrapolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, 1, Interpolations.GriddedInterpolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, 1, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Gridded{Linear{Throw{OnGrid}}}, Tuple{Vector{Float64}}}, Gridded{Linear{Throw{OnGrid}}}, Line{Nothing}}}, segs::Vector{QuadGK.Segment{Float64, ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}, I::ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, E::ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, numevals::Int64, x::Vector{Float64}, w::Vector{Float64}, wg::Vector{Float64}, n::Int64, atol::ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, rtol::Float64, maxevals::Int64, nrm::typeof(norm))
#
#     @ QuadGK ~/.julia/packages/QuadGK/7rND3/src/adapt.jl:115
#
#   [3] adapt
#
#     @ ~/.julia/packages/QuadGK/7rND3/src/adapt.jl:96 [inlined]
#
#   [4] do_quadgk(f::var"#17#18"{Interpolations.Extrapolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, 1, Interpolations.GriddedInterpolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, 1, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Gridded{Linear{Throw{OnGrid}}}, Tuple{Vector{Float64}}}, Gridded{Linear{Throw{OnGrid}}}, Line{Nothing}}}, s::Tuple{Float64, Float64}, n::Int64, atol::Nothing, rtol::Float64, maxevals::Int64, nrm::typeof(norm), _segbuf::Nothing, eval_segbuf::Nothing)
#
#     @ QuadGK ~/.julia/packages/QuadGK/7rND3/src/adapt.jl:87
#
#   [5] #50
#
#     @ ~/.julia/packages/QuadGK/7rND3/src/api.jl:83 [inlined]
#
#   [6] handle_infinities(workfunc::QuadGK.var"#50#51"{Nothing, Float64, Int64, Int64, typeof(norm), Nothing, Nothing}, f::var"#17#18"{Interpolations.Extrapolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, 1, Interpolations.GriddedInterpolation{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, 1, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Gridded{Linear{Throw{OnGrid}}}, Tuple{Vector{Float64}}}, Gridded{Linear{Throw{OnGrid}}}, Line{Nothing}}}, s::Tuple{Float64, Float64})
#
#     @ QuadGK ~/.julia/packages/QuadGK/7rND3/src/adapt.jl:189
#
#   [7] #quadgk#49
#
#     @ ~/.julia/packages/QuadGK/7rND3/src/api.jl:82 [inlined]
#
#   [8] quadgk
#
#     @ ~/.julia/packages/QuadGK/7rND3/src/api.jl:80 [inlined]
#
#   [9] dv(zarr::Vector{Float64}, h0::ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, ez::Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}})
#
#     @ Main ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/real_data/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X16sZmlsZQ==.jl:67
#
#  [10] a_iso(zarr::Vector{Float64}, h0::ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, rd::ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}, ez::Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}})
#
#     @ Main ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/real_data/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X16sZmlsZQ==.jl:87
#
#  [11] stats_model(__model__::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, __varinfo__::DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, Vector{Set{DynamicPPL.Selector}}}}, ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}, __context__::DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}, y::Vector{Float64}; int_grid::Vector{Float64}, X::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, data_x::Vector{Float64}, data_cov::BlockDiagonal{Float64, Matrix{Float64}})
#
#     @ Main ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/real_data/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X40sZmlsZQ==.jl:20
#
#  [12] stats_model
#
#     @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/real_data/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X40sZmlsZQ==.jl:1 [inlined]
#
#  [13] _evaluate!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:973 [inlined]
#
#  [14] evaluate_threadunsafe!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:946 [inlined]
#
#  [15] evaluate!!
#
#     @ ~/.julia/packages/DynamicPPL/MjWTB/src/model.jl:894 [inlined]
#
#  [16] logdensity(f::LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, θ::Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}})
#
#     @ DynamicPPL ~/.julia/packages/DynamicPPL/MjWTB/src/logdensityfunction.jl:140
#
#  [17] Fix1
#
#     @ ./operators.jl:1127 [inlined]
#
#  [18] chunk_mode_gradient!(result::DiffResults.MutableDiffResult{1, Float64, Tuple{Vector{Float64}}}, f::Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}}, x::Vector{Float64}, cfg::ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}})
#
#     @ ForwardDiff ~/.julia/packages/ForwardDiff/X74OO/src/gradient.jl:125
#
#  [19] gradient!
#
#     @ ~/.julia/packages/ForwardDiff/X74OO/src/gradient.jl:41 [inlined]
#
#  [20] gradient!
#
#     @ ~/.julia/packages/ForwardDiff/X74OO/src/gradient.jl:36 [inlined]
#
#  [21] logdensity_and_gradient
#
#     @ ~/.julia/packages/LogDensityProblemsAD/rBlLq/ext/LogDensityProblemsADForwardDiffExt.jl:118 [inlined]
#
#  [22] ∂logπ∂θ
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:180 [inlined]
#
#  [23] ∂H∂θ
#
#     @ ~/.julia/packages/AdvancedHMC/9NhHg/src/hamiltonian.jl:38 [inlined]
#
#  [24] step(lf::AdvancedHMC.Leapfrog{Float64}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{10}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{10}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDif ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/integrator.jl:229
#
#  [25] step
#
#     @ ~/.julia/packages/AdvancedHMC/9NhHg/src/integrator.jl:199 [inlined]
#
#  [26] build_tree(rng::Random.TaskLocalRNG, nt::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{10}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL. ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:639
#
#  [27] transition(rng::Random.TaskLocalRNG, τ::AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}, h::AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{10}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.D ...
#
#     @ AdvancedHMC ~/.julia/packages/AdvancedHMC/9NhHg/src/trajectory.jl:708
#
#  [28] transition
#
#     @ ~/.julia/packages/AdvancedHMC/9NhHg/src/sampler.jl:59 [inlined]
#
#  [29] step(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, spl::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, state::Turing.Inference.HMCState{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, AdvancedHMC.HMCKernel{AdvancedHMC.FullMomentumRefreshment, AdvancedHMC.Trajectory{AdvancedHMC.MultinomialTS, AdvancedHMC.Leapfrog{Float64}, AdvancedHMC.GeneralisedNoUTurn{Float64}}}, AdvancedHMC.Hamiltonian{AdvancedHMC.DiagEuclideanMetric{Float64, Vector{Float64}}, AdvancedHMC.GaussianKinetic, Base.Fix1{typeof(LogDensityProblems.logdensity), LogDensityProblemsADForwardDiffExt.ForwardDiffLogDensity{LogDensityFunction{DynamicPPL.TypedVarInfo{@NamedTuple{v_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:v_po, typeof(identity)}, Int64}, Vector{DiagNormal}, Vector{AbstractPPL.VarName{:v_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, omegam_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:omegam_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:omegam_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, s8_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:s8_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:s8_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, h_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:h_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:h_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}, r_po::DynamicPPL.Metadata{Dict{AbstractPPL.VarName{:r_po, typeof(identity)}, Int64}, Vector{Uniform{Float64}}, Vector{AbstractPPL.VarName{:r_po, typeof(identity)}}, Vector{Float64}, Vector{Set{DynamicPPL.Selector}}}}, Float64}, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.SamplingContext{DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, DynamicPPL.DefaultContext, Random.TaskLocalRNG}}, ForwardDiff.Chunk{10}, ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, ForwardDiff.GradientConfig{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DynamicPPL.DynamicPPLTag, Float64}, Float64, 10}}}}}, Turing.Inference.var"#∂logπ∂θ#32"{LogDensityProblemsADFo ...
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:261
#
#  [30] macro expansion
#
#     @ ~/.julia/packages/AbstractMCMC/1gucv/src/sample.jl:0 [inlined]
#
#  [31] (::AbstractMCMC.var"#29#30"{Nothing, Int64, Int64, Int64, UnionAll, Nothing, @Kwargs{nadapts::Int64}, Random.TaskLocalRNG, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Float64, Int64, Int64})()
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/1gucv/src/logging.jl:134
#
#  [32] with_logstate(f::AbstractMCMC.var"#29#30"{Nothing, Int64, Int64, Int64, UnionAll, Nothing, @Kwargs{nadapts::Int64}, Random.TaskLocalRNG, DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, Int64, Float64, Int64, Int64}, logstate::Base.CoreLogging.LogState)
#
#     @ Base.CoreLogging ./logging/logging.jl:524
#
#  [33] with_logger(f::Function, logger::LoggingExtras.TeeLogger{Tuple{LoggingExtras.EarlyFilteredLogger{TerminalLoggers.TerminalLogger, AbstractMCMC.var"#1#3"{Module}}, LoggingExtras.EarlyFilteredLogger{Base.CoreLogging.SimpleLogger, AbstractMCMC.var"#2#4"{Module}}}})
#
#     @ Base.CoreLogging ./logging/logging.jl:635
#
#  [34] with_progresslogger(f::Function, _module::Module, logger::Base.CoreLogging.SimpleLogger)
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/1gucv/src/logging.jl:157
#
#  [35] macro expansion
#
#     @ ~/.julia/packages/AbstractMCMC/1gucv/src/logging.jl:133 [inlined]
#
#  [36] mcmcsample(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; progress::Bool, progressname::String, callback::Nothing, num_warmup::Int64, discard_initial::Int64, thinning::Int64, chain_type::Type, initial_state::Nothing, kwargs::@Kwargs{nadapts::Int64})
#
#     @ AbstractMCMC ~/.julia/packages/AbstractMCMC/1gucv/src/sample.jl:168
#
#  [37] sample(rng::Random.TaskLocalRNG, model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, sampler::DynamicPPL.Sampler{NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}}, N::Int64; chain_type::Type, resume_from::Nothing, initial_state::Nothing, progress::Bool, nadapts::Int64, discard_adapt::Bool, discard_initial::Int64, kwargs::@Kwargs{})
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:123
#
#  [38] sample
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/hmc.jl:92 [inlined]
#
#  [39] #sample#4
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:276 [inlined]
#
#  [40] sample
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:267 [inlined]
#
#  [41] #sample#3
#
#     @ ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:264 [inlined]
#
#  [42] sample(model::DynamicPPL.Model{typeof(stats_model), (:y,), (:int_grid, :X, :data_x, :data_cov), (), Tuple{Vector{Float64}}, Tuple{Vector{Float64}, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Vector{Float64}, BlockDiagonal{Float64, Matrix{Float64}}}, DynamicPPL.DefaultContext}, alg::NUTS{AutoForwardDiff{nothing, Nothing}, (), AdvancedHMC.DiagEuclideanMetric}, N::Int64)
#
#     @ Turing.Inference ~/.julia/packages/Turing/QN7BL/src/mcmc/Inference.jl:258
#
#  [43] top-level scope
#
#     @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/real_data/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X41sZmlsZQ==.jl:2

# %%
# data posterior gp chains
hdata_p = group(chain_gp, :hdata).value.data[:,:,1];
aisodata_p = group(chain_gp, :aisodata).value.data[:,:,1];
aapdata_p =  group(chain_gp, :aapdata).value.data[:,:,1];
fs8data_p =  group(chain_gp, :fs8data).value.data[:,:,1];
#mudata_p =  group(chain_gp, :mudata).value.data[:,:,1];

# parameter chains
v_p = group(chain_gp, :v_po).value.data[:, :, 1];
omegam_p = group(chain_gp, :omegam_po).value.data[:, :, 1];
s8_p = group(chain_gp, :s8_po).value.data[:, :, 1];
# data mean / standard dev.
hpmean, hps = mean(hdata_p, dims=1), std(hdata_p, dims=1);
aisopmean, aisops = mean(aisodata_p, dims=1), std(aisodata_p, dims=1);
aappmean, aapps = mean(aapdata_p, dims=1), std(aapdata_p, dims=1);
fs8pmean, fs8ps = mean(fs8data_p, dims=1), std(fs8data_p, dims=1);
#mupmean, mups = mean(mudata_p, dims=1), std(mudata_p, dims=1);
# Out:
# UndefVarError: `chain_gp` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/real_data/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X42sZmlsZQ==.jl:1

# %%
p0 = plot(datahz.z, datahz.data, yerr=hz_err, seriestype=:scatter,label="H(z)")
p1 = plot(datafs8.z, dataDESI.data_dvrd, yerr=aiso_err, seriestype=:scatter,label="aiso(z)")
p2 = plot(datafs8.z, dataDESI.data_dhdm, yerr=aap_err, seriestype=:scatter, label="aap(z)")
p3 = plot(datafs8.z, dataDESI.data_fs8, yerr=fs8_err, seriestype=:scatter, label="fs8(z)")
#p4 = plot(fakedatamu.z, fakedatamu.data, yerr=mu_err, seriestype=:scatter, label="mu(z)")


plot!(p0, datahz.z, vec(hpmean), label="hz GP mean")
plot!(p0, datahz.z, vec(hpmean .- hps),  fillrange = vec(hpmean .+ hps), fillalpha=0.2, c=4, label="hz standard deviation")
plot!(p0, z_integ, vec(hz_lcdm_m), label="H(z) LCDM mean")
plot!(p0, z_integ, vec(hz_lcdm_m .- hz_lcdm_s),  fillrange = vec(hz_lcdm_m .+ hz_lcdm_s), fillalpha=0.2, c=1, label="H(z) LCDM standard deviation")


plot!(p1, datafs8.z, vec(aisopmean), label="a_iso GP mean")
plot!(p1, datafs8.z, vec(aisopmean .- aisops),  fillrange = vec(aisopmean .+ aisops), fillalpha=0.2, c=4, label="a_iso standard deviation")
plot!(p1, z_integ, vec(aiso_lcdm_m), label="a_iso LCDM mean")
plot!(p1, z_integ, vec(aiso_lcdm_m .- aiso_lcdm_s),  fillrange = vec(aiso_lcdm_m .+ aiso_lcdm_s), fillalpha=0.2, c=1, label="a_iso LCDM standard deviation")


plot!(p2, datafs8.z, vec(aappmean), label="a_ap GP mean")
plot!(p2, datafs8.z, vec(aappmean .- aapps),  fillrange = vec(aappmean .+ aapps), fillalpha=0.2, c=4, label="a_ap standard deviation")
plot!(p2, z_integ, vec(aap_lcdm_m), label="a_ap LCDM mean")
plot!(p2, z_integ, vec(aap_lcdm_m .- aap_lcdm_s),  fillrange = vec(aap_lcdm_m .+ aap_lcdm_s), fillalpha=0.2, c=1, label="a_ap LCDM standard deviation")


plot!(p3, datafs8.z, vec(fs8pmean), label="fs8 GP mean")
plot!(p3, datafs8.z, vec(fs8pmean .- fs8ps),  fillrange = vec(fs8pmean .+ fs8ps), fillalpha=0.2, c=4, label="fs8 standard deviation")
plot!(p3, z_integ, vec(fs8_lcdm_m), label="fs8 LCDM mean")
plot!(p3, z_integ, vec(fs8_lcdm_m .- fs8_lcdm_s),  fillrange = vec(fs8_lcdm_m .+ fs8_lcdm_s), fillalpha=0.2, c=1, label="fs8 LCDM standard deviation")


# plot!(p4, fakedatamu.z, vec(mupmean), label="mu GP mean")
# plot!(p4, fakedatamu.z, vec(mupmean .- mups),  fillrange = vec(mupmean .+ mups), fillalpha=0.2, c=4, label="mu standard deviation")
# plot!(p4, fakedatamu.z, vec(mu_lcdm_m), label="mu LCDM mean")
# plot!(p4, fakedatamu.z, vec(mu_lcdm_m .- mu_lcdm_s),  fillrange = vec(mu_lcdm_m .+ mu_lcdm_s), fillalpha=0.2, c=1, label="mu LCDM standard deviation")

plot(p0, p1, p2, p3, layout=(2,3), size=(1600,1000))
# Out:
# UndefVarError: `hpmean` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/Desktop/MSci Project - UCL 2025-26/Cosmography_GP/real_data/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X43sZmlsZQ==.jl:8
